# %% [markdown]
# # Feature engineering

# %%
# %config Completer.use_jedi = False
import pandas as pd
import torch
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import numpy as np
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.optim.lr_scheduler import _LRScheduler
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
from multiprocessing import cpu_count
from pathlib import Path
import tsfresh
from tsfresh.feature_extraction import EfficientFCParameters, MinimalFCParameters, ComprehensiveFCParameters
from tsfresh.utilities.dataframe_functions import roll_time_series
from tqdm import tqdm, tqdm_notebook
from sklearn.metrics import f1_score
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 500)

# %%
data = pd.read_csv('../FIT5149_A2_data/train_data_withlabels.csv')
data.rename(columns={"Unnamed: 0":"id"}, inplace= True)

# %%
data.head(100)
# Out:
#         id   load  ac  ev  oven  wash  dryer  hourofday dayofweek    dif  \
# 0   105541  2.245   0   0     0     0      0          0       Sun  0.987
# 1   105542  2.259   0   0     0     0      0          0       Sun  0.014
# 2   105543  2.269   0   0     0     0      0          0       Sun  0.010
# 3   105544  2.268   0   0     0     0      0          0       Sun -0.001
# 4   105545  2.270   0   0     0     0      0          0       Sun  0.002
# 5   105546  2.259   0   0     0     0      0          0       Sun -0.011
# 6   105547  2.250   0   0     0     0      0          0       Sun -0.009
# 7   105548  2.251   0   0     0     0      0          0       Sun  0.001
# 8   105549  2.264   0   0     0     0      0          0       Sun  0.013
# 9   105550  2.277   0   0     0     0      0          0       Sun  0.013
# 10  105551  2.307   0   0     0     0      0          0       Sun  0.030
# 11  105552  2.384   0   0     0     0      0          0       Sun  0.077
# 12  105553  2.382   0   0     0     0      0          0       Sun -0.002
# 13  105554  2.441   0   0     0     0      0          0       Sun  0.059
# 14  105555  2.449   0   0     0     0      0          0       Sun  0.008
# 15  105556  2.440   0   0     0     0      0          0       Sun -0.009
# 16  105557  2.444   0   0     0     0      0          0       Sun  0.004
# 17  105558  2.424   0   0     0     0      0          0       Sun -0.020
# 18  105559  2.425   0   0     0     0      0          0       Sun  0.001
# 19  105560  2.432   0   0     0     0      0          0       Sun  0.007
# 20  105561  2.431   0   0     0     0      0          0       Sun -0.001
# 21  105562  2.418   0   0     0     0      0          0       Sun -0.013
# 22  105563  2.420   0   0     0     0      0          0       Sun  0.002
# 23  105564  3.361   1   0     0     0      0          0       Sun  0.941
# 24  105565  6.167   1   0     0     0      0          0       Sun  2.806
# 25  105566  6.204   1   0     0     0      0          0       Sun  0.037
# 26  105567  6.215   1   0     0     0      0          0       Sun  0.011
# 27  105568  6.207   1   0     0     0      0          0       Sun -0.008
# 28  105569  6.199   1   0     0     0      0          0       Sun -0.008
# 29  105570  6.178   1   0     0     0      0          0       Sun -0.021
# 30  105571  6.183   1   0     0     0      0          0       Sun  0.005
# 31  105572  6.155   1   0     0     0      0          0       Sun -0.028
# 32  105573  6.143   1   0     0     0      0          0       Sun -0.012
# 33  105574  5.419   1   0     0     0      0          0       Sun -0.724
# 34  105575  4.915   1   0     0     0      0          0       Sun -0.504
# 35  105576  4.881   1   0     0     0      0          0       Sun -0.034
# 36  105577  4.872   1   0     0     0      0          0       Sun -0.009
# 37  105578  2.491   1   0     0     0      0          0       Sun -2.381
# 38  105579  1.965   0   0     0     0      0          0       Sun -0.526
# 39  105580  1.243   0   0     0     0      0          0       Sun -0.722
# 40  105581  1.087   0   0     0     0      0          0       Sun -0.156
# 41  105582  1.142   0   0     0     0      0          0       Sun  0.055
# 42  105583  1.139   0   0     0     0      0          0       Sun -0.003
# 43  105584  1.141   0   0     0     0      0          0       Sun  0.002
# 44  105585  1.139   0   0     0     0      0          0       Sun -0.002
# 45  105586  1.029   0   0     0     0      0          0       Sun -0.110
# 46  105587  1.000   0   0     0     0      0          0       Sun -0.029
# 47  105588  1.054   0   0     0     0      0          0       Sun  0.054
# 48  105589  1.008   0   0     0     0      0          0       Sun -0.046
# 49  105590  1.027   0   0     0     0      0          0       Sun  0.019
# 50  105591  1.081   0   0     0     0      0          0       Sun  0.054
# 51  105592  1.075   0   0     0     0      0          0       Sun -0.006
# 52  105593  1.058   0   0     0     0      0          0       Sun -0.017
# 53  105594  1.062   0   0     0     0      0          0       Sun  0.004
# 54  105595  1.051   0   0     0     0      0          0       Sun -0.011
# 55  105596  1.056   0   0     0     0      0          0       Sun  0.005
# 56  105597  1.050   0   0     0     0      0          0       Sun -0.006
# 57  105598  1.050   0   0     0     0      0          0       Sun  0.000
# 58  105599  1.054   0   0     0     0      0          0       Sun  0.004
# 59  105600  1.047   0   0     0     0      0          0       Sun -0.007
# 60  105601  1.045   0   0     0     0      0          1       Sun -0.002
# 61  105602  1.039   0   0     0     0      0          1       Sun -0.006
# 62  105603  1.044   0   0     0     0      0          1       Sun  0.005
# 63  105604  1.039   0   0     0     0      0          1       Sun -0.005
# 64  105605  1.035   0   0     0     0      0          1       Sun -0.004
# 65  105606  1.033   0   0     0     0      0          1       Sun -0.002
# 66  105607  1.033   0   0     0     0      0          1       Sun  0.000
# 67  105608  1.033   0   0     0     0      0          1       Sun  0.000
# 68  105609  1.031   0   0     0     0      0          1       Sun -0.002
# 69  105610  1.033   0   0     0     0      0          1       Sun  0.002
# 70  105611  1.043   0   0     0     0      0          1       Sun  0.010
# 71  105612  1.044   0   0     0     0      0          1       Sun  0.001
# 72  105613  1.030   0   0     0     0      0          1       Sun -0.014
# 73  105614  1.028   0   0     0     0      0          1       Sun -0.002
# 74  105615  1.028   0   0     0     0      0          1       Sun  0.000
# 75  105616  1.026   0   0     0     0      0          1       Sun -0.002
# 76  105617  1.028   0   0     0     0      0          1       Sun  0.002
# 77  105618  2.892   1   0     0     0      0          1       Sun  1.864
# 78  105619  4.789   1   0     0     0      0          1       Sun  1.897
# 79  105620  4.805   1   0     0     0      0          1       Sun  0.016
# 80  105621  4.802   1   0     0     0      0          1       Sun -0.003
# 81  105622  4.802   1   0     0     0      0          1       Sun  0.000
# 82  105623  4.793   1   0     0     0      0          1       Sun -0.009
# 83  105624  4.795   1   0     0     0      0          1       Sun  0.002
# 84  105625  4.792   1   0     0     0      0          1       Sun -0.003
# 85  105626  4.791   1   0     0     0      0          1       Sun -0.001
# 86  105627  4.789   1   0     0     0      0          1       Sun -0.002
# 87  105628  4.788   1   0     0     0      0          1       Sun -0.001
# 88  105629  4.779   1   0     0     0      0          1       Sun -0.009
# 89  105630  4.113   1   0     0     0      0          1       Sun -0.666
# 90  105631  1.998   0   0     0     0      0          1       Sun -2.115
# 91  105632  1.676   0   0     0     0      0          1       Sun -0.322
# 92  105633  0.972   0   0     0     0      0          1       Sun -0.704
# 93  105634  0.969   0   0     0     0      0          1       Sun -0.003
# 94  105635  0.969   0   0     0     0      0          1       Sun  0.000
# 95  105636  0.967   0   0     0     0      0          1       Sun -0.002
# 96  105637  0.970   0   0     0     0      0          1       Sun  0.003
# 97  105638  0.969   0   0     0     0      0          1       Sun -0.001
# 98  105639  0.971   0   0     0     0      0          1       Sun  0.002
# 99  105640  0.968   0   0     0     0      0          1       Sun -0.003
#
#     absdif    max       var   entropy  nonlinear     hurst
# 0    0.987  6.215  3.074549  0.678886   0.052903  0.994071
# 1    0.014  6.215  3.172867  0.667450   0.054829  0.994154
# 2    0.010  6.215  3.270112  0.647777   0.056991  0.994220
# 3    0.001  6.215  3.303763  0.629227   0.057606  0.994150
# 4    0.002  6.215  3.302744  0.621295   0.082640  0.994041
# 5    0.011  6.215  3.298258  0.626956   0.089788  0.993986
# 6    0.009  6.215  3.289135  0.640121   0.085276  0.993927
# 7    0.001  6.215  3.238982  0.651916   0.354203  0.992703
# 8    0.013  6.215  3.203236  0.655600   0.372529  0.992474
# 9    0.013  6.215  3.196127  0.650006   0.366578  0.992308
# 10   0.030  6.215  3.192309  0.638484   0.481547  0.992326
# 11   0.077  6.215  3.170742  0.627788   0.628848  0.992288
# 12   0.002  6.215  3.136232  0.625361   0.803450  0.992176
# 13   0.059  6.215  3.093735  0.633304   0.414832  0.992695
# 14   0.008  6.215  3.119437  0.645965   0.203071  0.993283
# 15   0.009  6.215  3.159763  0.655178   0.264652  0.993464
# 16   0.004  6.215  3.188556  0.655996   0.316233  0.993585
# 17   0.020  6.215  3.193862  0.648712   0.307894  0.993624
# 18   0.001  6.215  3.199371  0.638446   0.314720  0.993653
# 19   0.007  6.215  3.205613  0.632546   0.311370  0.993680
# 20   0.001  6.215  3.207214  0.636003   0.303863  0.993696
# 21   0.013  6.215  3.206899  0.646308   0.304838  0.993704
# 22   0.002  6.215  3.207899  0.655493   0.305610  0.993710
# 23   0.941  6.215  3.208320  0.656899   0.305501  0.993711
# 24   2.806  6.215  3.209429  0.648374   0.306835  0.993709
# 25   0.037  6.215  3.210533  0.632310   0.306477  0.993702
# 26   0.011  6.215  3.211904  0.615711   0.302953  0.993689
# 27   0.008  6.215  3.210240  0.608209   0.302356  0.993666
# 28   0.008  6.215  3.208092  0.615346   0.301602  0.993636
# 29   0.021  6.215  3.206152  0.631540   0.329941  0.993641
# 30   0.005  6.215  3.216751  0.645637   0.365689  0.993821
# 31   0.028  6.215  3.256580  0.650416   0.370147  0.993804
# 32   0.012  6.215  3.295518  0.645002   0.374179  0.993826
# 33   0.724  6.215  3.334012  0.632772   0.381406  0.993847
# 34   0.504  6.215  3.371874  0.619938   0.388666  0.993867
# 35   0.034  6.215  3.409023  0.613839   0.398533  0.993886
# 36   0.009  6.215  3.445241  0.617621   0.409033  0.993904
# 37   2.381  6.215  3.480564  0.626899   0.418999  0.993920
# 38   0.526  6.215  3.515182  0.634223   0.427978  0.993935
# 39   0.722  6.215  3.548980  0.634870   0.437536  0.993950
# 40   0.156  6.215  3.581557  0.628442   0.443970  0.993964
# 41   0.055  6.215  3.613384  0.619074   0.441583  0.993980
# 42   0.003  6.215  3.645115  0.612822   0.457425  0.993994
# 43   0.002  6.215  3.675935  0.613976   0.459602  0.994010
# 44   0.002  6.215  3.705639  0.621082   0.474339  0.994023
# 45   0.110  6.215  3.734309  0.628156   0.496728  0.994036
# 46   0.029  6.215  3.761829  0.629605   0.519871  0.994038
# 47   0.054  6.215  3.767163  0.623449   0.359024  0.993422
# 48   0.046  6.215  3.867491  0.611705   0.771187  0.992654
# 49   0.019  6.215  3.966043  0.600396   0.851082  0.992856
# 50   0.054  6.215  4.061264  0.596993   0.976535  0.993027
# 51   0.006  6.215  4.153415  0.604822   1.166487  0.993156
# 52   0.017  6.215  4.241770  0.619109   1.443578  0.993275
# 53   0.004  6.215  4.327201  0.631509   1.076250  0.993781
# 54   0.011  6.215  4.399559  0.636572   0.224770  0.994912
# 55   0.005  6.215  4.265675  0.633665   0.185385  0.994842
# 56   0.006  6.215  4.126092  0.625356   0.154177  0.994783
# 57   0.000  6.207  3.983979  0.618655   0.132095  0.994751
# 58   0.004  6.199  3.841057  0.621217   0.120602  0.994633
# 59   0.007  6.183  3.653709  0.634225   0.125292  0.994462
# 60   0.002  6.183  3.419947  0.651004   0.041751  0.993463
# 61   0.006  6.155  3.181012  0.662795   0.004254  0.993081
# 62   0.005  6.143  2.955749  0.665795   0.097880  0.992603
# 63   0.005  5.419  2.717530  0.660638   0.052152  0.992378
# 64   0.004  4.915  2.554641  0.651960   0.046160  0.992148
# 65   0.002  4.881  2.434363  0.645661   0.038756  0.991812
# 66   0.000  4.872  2.308835  0.645040   0.035617  0.991370
# 67   0.000  4.805  2.175881  0.649113   0.225180  0.992812
# 68   0.002  4.805  2.182119  0.654323   0.116963  0.992962
# 69   0.002  4.805  2.194315  0.657092   0.208099  0.993149
# 70   0.010  4.805  2.200893  0.655618   0.256056  0.993184
# 71   0.001  4.805  2.203979  0.651505   0.256358  0.993204
# 72   0.014  4.805  2.207815  0.648545   0.263922  0.993222
# 73   0.002  4.805  2.210760  0.649763   0.271417  0.993236
# 74   0.000  4.805  2.213559  0.654922   0.281648  0.993249
# 75   0.002  4.805  2.215038  0.660354   0.308192  0.993261
# 76   0.002  4.805  2.213971  0.661415   0.304146  0.993265
# 77   1.864  4.805  2.212231  0.655722   0.302197  0.993268
# 78   1.897  4.805  2.211245  0.644639   0.304048  0.993271
# 79   0.016  4.805  2.209593  0.633056   0.296619  0.993271
# 80   0.003  4.805  2.208296  0.627190   0.294420  0.993272
# 81   0.000  4.805  2.208247  0.630739   0.295393  0.993274
# 82   0.009  4.805  2.208396  0.641878   0.294677  0.993276
# 83   0.002  4.805  2.208045  0.654612   0.293810  0.993276
# 84   0.003  4.805  2.208020  0.662809   0.292945  0.993276
# 85   0.001  4.805  2.207843  0.663277   0.291750  0.993275
# 86   0.002  4.805  2.207817  0.657314   0.291751  0.993274
# 87   0.001  4.805  2.207665  0.649237   0.291231  0.993272
# 88   0.009  4.805  2.207614  0.643730   0.290613  0.993269
# 89   0.666  4.805  2.207844  0.643436   0.290770  0.993266
# 90   2.115  4.805  2.207972  0.647700   0.290887  0.993261
# 91   0.322  4.805  2.207844  0.653173   0.291236  0.993255
# 92   0.704  4.805  2.207408  0.656280   0.290655  0.993248
# 93   0.003  4.805  2.207255  0.655092   0.289747  0.993239
# 94   0.000  4.805  2.206997  0.651211   0.289076  0.993229
# 95   0.002  4.805  2.206635  0.648434   0.288257  0.993217
# 96   0.003  4.805  2.206222  0.649800   0.287343  0.993203
# 97   0.001  4.805  2.205808  0.655093   0.286437  0.993186
# 98   0.002  4.805  2.205445  0.660645   0.285494  0.993165
# 99   0.003  4.805  2.205055  0.661788   0.284635  0.993141

# %%
data.dtypes
# Out:
# id             int64
# load         float64
# ac             int64
# ev             int64
# oven           int64
# wash           int64
# dryer          int64
# hourofday      int64
# dayofweek     object
# dif          float64
# absdif       float64
# max          float64
# var          float64
# entropy      float64
# nonlinear    float64
# hurst        float64
# dtype: object

# %%
x_train = data.loc[:,data.columns.difference(['ac', 'ev', 'oven', 'wash', 'dryer'])]
# x_train.drop('Unnamed: 0', axis = 1, inplace = True)
y_train = data[['ac', 'ev', 'oven', 'wash', 'dryer']]

# %%
le = preprocessing.LabelEncoder()
le.fit(x_train['dayofweek'])
le.classes_
x_train['dayofweek'] = le.transform(x_train['dayofweek'])

# %%
x_train['dummy_id'] = 1
x_train.columns
# Out:
# Index(['absdif', 'dayofweek', 'dif', 'entropy', 'hourofday', 'hurst', 'id',
#        'load', 'max', 'nonlinear', 'var', 'dummy_id'],
#       dtype='object')

# %%
# Scale
scale_list = ['absdif', 'dayofweek', 'dif', 'entropy', 'hourofday', 'hurst',
       'load', 'max', 'nonlinear', 'var']
scaler = preprocessing.StandardScaler().fit(x_train[scale_list])
x_train[scale_list] = scaler.transform(x_train[scale_list])
x_train
# Out:
#           absdif  dayofweek       dif   entropy  hourofday      hurst      id  \
# 0       1.633999  -0.006818  1.859011 -0.306037  -1.659524   0.325913  105541
# 1      -0.287489  -0.006818  0.026370 -0.427219  -1.659524   0.327174  105542
# 2      -0.295388  -0.006818  0.018836 -0.635696  -1.659524   0.328183  105543
# 3      -0.313161  -0.006818 -0.001882 -0.832269  -1.659524   0.327108  105544
# 4      -0.311186  -0.006818  0.003768 -0.916324  -1.659524   0.325441  105545
# ...          ...        ...       ...       ...        ...        ...     ...
# 417715 -0.309212   0.992434 -0.005649 -7.500160   1.375005 -14.864864  523256
# 417716 -0.066310   0.992434 -0.237319 -7.500160   1.375005 -14.864864  523257
# 417717  2.485141   0.992434 -2.670795 -7.500160   1.375005 -14.864864  523258
# 417718 -0.249967   0.992434 -0.062154 -7.500160   1.375005 -14.864864  523259
# 417719 -0.311186   0.992434 -0.003766 -7.500160   1.375005 -14.864864  523260
#
#             load       max  nonlinear       var  dummy_id
# 0       0.031914  1.050126  -0.542338  0.673127         1
# 1       0.039319  1.050126  -0.541600  0.728126         1
# 2       0.044609  1.050126  -0.540772  0.782525         1
# 3       0.044080  1.050126  -0.540536  0.801349         1
# 4       0.045138  1.050126  -0.530947  0.800779         1
# ...          ...       ...        ...       ...       ...
# 417715  0.189539 -1.866220  -0.562601 -1.046775         1
# 417716  0.122892 -1.866220  -0.562601 -1.046775         1
# 417717 -0.627149 -1.866220  -0.562601 -1.046775         1
# 417718 -0.644604 -1.866220  -0.562601 -1.046775         1
# 417719 -0.645662 -1.866220  -0.562601 -1.046775         1
#
# [417720 rows x 12 columns]

# %%
extra_len = pd.DataFrame(x_train.iloc[0:1,:].values.repeat(29, axis = 0), columns=x_train.columns)
extra_len['id'] = list(range(105541-29,105541))
x_train = pd.concat([extra_len, x_train])
x_train
# Out:
#           absdif  dayofweek       dif   entropy  hourofday      hurst      id  \
# 0       1.633999  -0.006818  1.859011 -0.306037  -1.659524   0.325913  105512
# 1       1.633999  -0.006818  1.859011 -0.306037  -1.659524   0.325913  105513
# 2       1.633999  -0.006818  1.859011 -0.306037  -1.659524   0.325913  105514
# 3       1.633999  -0.006818  1.859011 -0.306037  -1.659524   0.325913  105515
# 4       1.633999  -0.006818  1.859011 -0.306037  -1.659524   0.325913  105516
# ...          ...        ...       ...       ...        ...        ...     ...
# 417715 -0.309212   0.992434 -0.005649 -7.500160   1.375005 -14.864864  523256
# 417716 -0.066310   0.992434 -0.237319 -7.500160   1.375005 -14.864864  523257
# 417717  2.485141   0.992434 -2.670795 -7.500160   1.375005 -14.864864  523258
# 417718 -0.249967   0.992434 -0.062154 -7.500160   1.375005 -14.864864  523259
# 417719 -0.311186   0.992434 -0.003766 -7.500160   1.375005 -14.864864  523260
#
#             load       max  nonlinear       var  dummy_id
# 0       0.031914  1.050126  -0.542338  0.673127       1.0
# 1       0.031914  1.050126  -0.542338  0.673127       1.0
# 2       0.031914  1.050126  -0.542338  0.673127       1.0
# 3       0.031914  1.050126  -0.542338  0.673127       1.0
# 4       0.031914  1.050126  -0.542338  0.673127       1.0
# ...          ...       ...        ...       ...       ...
# 417715  0.189539 -1.866220  -0.562601 -1.046775       1.0
# 417716  0.122892 -1.866220  -0.562601 -1.046775       1.0
# 417717 -0.627149 -1.866220  -0.562601 -1.046775       1.0
# 417718 -0.644604 -1.866220  -0.562601 -1.046775       1.0
# 417719 -0.645662 -1.866220  -0.562601 -1.046775       1.0
#
# [417749 rows x 12 columns]

# %%
# x_train_rolled = roll_time_series(x_train, column_id="dummy_id", column_sort="id",
#                             max_timeshift = 29, min_timeshift = 29)
# np.save("np_x_train_rolled_new.npy",np.array(x_train_rolled))
x_train_rolled = np.load('../np_x_train_rolled_new.npy', allow_pickle= True)
x_train_rolled = pd.DataFrame(x_train_rolled, columns=x_train.columns)
x_train_rolled = x_train_rolled[['id', 'load', 'absdif', 'dayofweek', 'dif', 'entropy', 'hourofday', 'hurst', 
        'max', 'nonlinear', 'var']]
x_train_rolled
load	hourofday	dayofweek	dif	absdif	max	var	entropy	nonlinear	hurst
# Out:
#                    id      load    absdif dayofweek       dif   entropy  \
# 0         (1, 105541)  0.031914  1.633999 -0.006818  1.859011 -0.306037
# 1         (1, 105541)  0.031914  1.633999 -0.006818  1.859011 -0.306037
# 2         (1, 105541)  0.031914  1.633999 -0.006818  1.859011 -0.306037
# 3         (1, 105541)  0.031914  1.633999 -0.006818  1.859011 -0.306037
# 4         (1, 105541)  0.031914  1.633999 -0.006818  1.859011 -0.306037
# ...               ...       ...       ...       ...       ...       ...
# 12531595  (1, 523260)  0.189539 -0.309212  0.992434 -0.005649  -7.50016
# 12531596  (1, 523260)  0.122892  -0.06631  0.992434 -0.237319  -7.50016
# 12531597  (1, 523260) -0.627149  2.485141  0.992434 -2.670795  -7.50016
# 12531598  (1, 523260) -0.644604 -0.249967  0.992434 -0.062154  -7.50016
# 12531599  (1, 523260) -0.645662 -0.311186  0.992434 -0.003766  -7.50016
#
#          hourofday      hurst       max nonlinear       var
# 0        -1.659524   0.325913  1.050126 -0.542338  0.673127
# 1        -1.659524   0.325913  1.050126 -0.542338  0.673127
# 2        -1.659524   0.325913  1.050126 -0.542338  0.673127
# 3        -1.659524   0.325913  1.050126 -0.542338  0.673127
# 4        -1.659524   0.325913  1.050126 -0.542338  0.673127
# ...            ...        ...       ...       ...       ...
# 12531595  1.375005 -14.864864  -1.86622 -0.562601 -1.046775
# 12531596  1.375005 -14.864864  -1.86622 -0.562601 -1.046775
# 12531597  1.375005 -14.864864  -1.86622 -0.562601 -1.046775
# 12531598  1.375005 -14.864864  -1.86622 -0.562601 -1.046775
# 12531599  1.375005 -14.864864  -1.86622 -0.562601 -1.046775
#
# [12531600 rows x 11 columns]

# %%
print(len(x_train_rolled)/30)
print(len(x_train)-29)
# Out:
# 417720.0
# 417720

# %%
y_train['transformed'] = y_train.apply(lambda x: ''.join(x.astype(str)),axis = 1)
le_y = preprocessing.LabelEncoder()
y_train['encoded'] = le_y.fit_transform(y_train['transformed'])
y_train_transformed = y_train['encoded']
y_train_transformed = np.array(y_train_transformed)
y_train_transformed
# Out:
# <ipython-input-12-242b35176f15>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train['transformed'] = y_train.apply(lambda x: ''.join(x.astype(str)),axis = 1)
# <ipython-input-12-242b35176f15>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train['encoded'] = le_y.fit_transform(y_train['transformed'])
# array([0, 0, 0, ..., 0, 0, 0])

# %%
x_train_rolled.drop('id', axis=1, inplace=True)
x_train_rolled = np.reshape(x_train_rolled.to_numpy(dtype=np.float64), [-1 , 30, int(x_train_rolled.shape[1])])
x_train_rolled.shape #(417720, 30, 10)
# Out:
# (417720, 30, 10)

# %%
def absfft(x):
    return np.abs(np.fft.rfft(x))
x_train_fft = np.copy(x_train_rolled)
x_train_fft = np.apply_along_axis(absfft, 1, x_train_fft)
x_train_fft
# Out:
# array([[[9.57422367e-01, 4.90199688e+01, 2.04529474e-01, ...,
#          3.15037666e+01, 1.62701326e+01, 2.01938024e+01],
#         [0.00000000e+00, 0.00000000e+00, 9.75471029e-18, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.01570512e-15, 3.96759812e-18, ...,
#          5.07852559e-16, 2.53926279e-16, 2.53926279e-16],
#         ...,
#         [0.00000000e+00, 2.15894788e-16, 8.43339014e-19, ...,
#          1.07947394e-16, 5.39736969e-17, 5.39736969e-17],
#         [0.00000000e+00, 0.00000000e+00, 1.02526137e-18, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[9.64827570e-01, 4.70984811e+01, 2.04529474e-01, ...,
#          3.15037666e+01, 1.62693947e+01, 2.02488017e+01],
#         [7.40520390e-03, 1.92148767e+00, 9.75471029e-18, ...,
#          0.00000000e+00, 7.37854077e-04, 5.49992849e-02],
#         [7.40520390e-03, 1.92148767e+00, 3.96759812e-18, ...,
#          5.07852559e-16, 7.37854077e-04, 5.49992849e-02],
#         ...,
#         [7.40520390e-03, 1.92148767e+00, 8.43339014e-19, ...,
#          1.07947394e-16, 7.37854077e-04, 5.49992849e-02],
#         [7.40520390e-03, 1.92148767e+00, 1.02526137e-18, ...,
#          0.00000000e+00, 7.37854077e-04, 5.49992849e-02],
#         [7.40520390e-03, 1.92148767e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 7.37854077e-04, 5.49992849e-02]],
#
#        [[9.77522206e-01, 4.51690942e+01, 2.04529474e-01, ...,
#          3.15037666e+01, 1.62678290e+01, 2.03581997e+01],
#         [1.99973750e-02, 3.82977917e+00, 9.75471029e-18, ...,
#          0.00000000e+00, 2.29264034e-03, 1.63595551e-01],
#         [1.96913428e-02, 3.76672408e+00, 3.96759812e-18, ...,
#          5.07852559e-16, 2.25985145e-03, 1.61202067e-01],
#         ...,
#         [6.65076223e-03, 8.00679126e-01, 8.43339014e-19, ...,
#          1.07947394e-16, 9.40856851e-04, 6.32422473e-02],
#         [5.66450468e-03, 4.02602655e-01, 1.02526137e-18, ...,
#          0.00000000e+00, 8.57869724e-04, 5.67642842e-02],
#         [5.28943136e-03, 7.89922989e-03, 0.00000000e+00, ...,
#          0.00000000e+00, 8.27917763e-04, 5.43987170e-02]],
#
#        ...,
#
#        [[1.08797961e+01, 2.09989743e+00, 2.97730325e+01, ...,
#          5.35897204e+01, 1.64929664e+01, 3.12496486e+01],
#         [1.72494683e+00, 5.61980658e+00, 0.00000000e+00, ...,
#          2.38376345e+00, 3.82963773e-01, 1.52762419e-01],
#         [2.04401919e+00, 3.44320309e+00, 0.00000000e+00, ...,
#          2.34451601e+00, 3.76659339e-01, 1.50247264e-01],
#         ...,
#         [6.40332882e-01, 3.64724009e+00, 0.00000000e+00, ...,
#          4.98342261e-01, 8.01808641e-02, 3.19360646e-02],
#         [3.38950172e-01, 4.93535948e+00, 0.00000000e+00, ...,
#          2.50543635e-01, 4.04966347e-02, 1.60560240e-02],
#         [1.30648955e-01, 5.20954211e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.47734964e-03, 3.89745716e-05]],
#
#        [[1.11093574e+01, 2.06830051e+00, 2.97730325e+01, ...,
#          5.47881673e+01, 1.66832642e+01, 3.13264310e+01],
#         [1.54377624e+00, 5.64173442e+00, 0.00000000e+00, ...,
#          1.19844694e+00, 1.94775153e-01, 7.68214260e-02],
#         [1.98496148e+00, 3.45257049e+00, 0.00000000e+00, ...,
#          1.19844694e+00, 1.94775153e-01, 7.68214260e-02],
#         ...,
#         [4.12045183e-01, 3.63977806e+00, 0.00000000e+00, ...,
#          1.19844694e+00, 1.94775153e-01, 7.68214260e-02],
#         [2.00351183e-01, 4.90975748e+00, 0.00000000e+00, ...,
#          1.19844694e+00, 1.94775153e-01, 7.68214260e-02],
#         [9.89123664e-02, 5.17794519e+00, 0.00000000e+00, ...,
#          1.19844694e+00, 1.94775153e-01, 7.68214260e-02]],
#
#        [[1.13389187e+01, 2.06830051e+00, 2.97730325e+01, ...,
#          5.59866143e+01, 1.68780394e+01, 3.14032524e+01],
#         [1.41555980e+00, 5.64173442e+00, 0.00000000e+00, ...,
#          2.49720583e-15, 0.00000000e+00, 0.00000000e+00],
#         [2.04608872e+00, 3.45257049e+00, 0.00000000e+00, ...,
#          1.01570512e-15, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [6.35530774e-01, 3.63977806e+00, 0.00000000e+00, ...,
#          2.15894788e-16, 0.00000000e+00, 0.00000000e+00],
#         [3.64654383e-01, 4.90975748e+00, 0.00000000e+00, ...,
#          2.62466909e-16, 0.00000000e+00, 0.00000000e+00],
#         [1.30648955e-01, 5.17794519e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]])

# %%
print(x_train_rolled.shape)
print(x_train_fft.shape)
# Out:
# (417720, 30, 10)
# (417720, 16, 10)

# %%
# num_vars = x_train_rolled.shape[2]
# for i in range(num_vars):
#     mean_s = np.mean(x_train_rolled[:,:,i])
#     sd_s = np.std(x_train_rolled[:,:,i])
#     x_train_rolled[:,:,i] = (x_train_rolled[:,:,i]-mean_s)/sd_s

# num_vars_fft = x_train_fft.shape[2]
# for i in range(num_vars_fft):
#     mean_s = np.mean(x_train_fft[:,:,i])
#     sd_s = np.std(x_train_fft[:,:,i])
#     x_train_fft[:,:,i] = (x_train_fft[:,:,i]-mean_s)/sd_s

# %%
x_train = x_train_rolled.transpose(0,2,1)
x_train_fft = x_train_fft.transpose(0,2,1)

# %%
print(x_train.shape)
print(x_train_fft.shape)
# Out:
# (417720, 10, 30)
# (417720, 10, 16)

# %%
plt.hist(y_train_transformed)
# Out:
# (array([3.05135e+05, 5.84700e+03, 3.59200e+03, 1.46000e+02, 9.53960e+04,
#         4.59300e+03, 2.26400e+03, 1.87000e+02, 4.79000e+02, 8.10000e+01]),
#  array([ 0. ,  1.9,  3.8,  5.7,  7.6,  9.5, 11.4, 13.3, 15.2, 17.1, 19. ]),
#  <BarContainer object of 10 artists>)

# %%
def build_datasets(data, target, train_size, valid_pct = 0.2, seed = None):
    x, x_fft = data
    idx = np.arange(train_size)
#     train_idx, val_idx = train_test_split(idx, test_size = valid_pct, random_state = seed)
    train_idx, val_idx = idx[:round(train_size * (1-valid_pct))], idx[round(train_size * valid_pct):]
    train_ds = TensorDataset(torch.tensor(x[:train_size][train_idx]).float(),
                            torch.tensor(x_fft[:train_size][train_idx]).float(),
                            torch.tensor(target[:train_size][train_idx]).long())
    val_ds = TensorDataset(torch.tensor(x[:train_size][val_idx]).float(),
                            torch.tensor(x_fft[:train_size][val_idx]).float(),
                            torch.tensor(target[:train_size][val_idx]).long())
#     test_ds = TensorDataset(torch.tensor(x[train_size:]).float(),
#                             torch.tensor(x_fft[train_size:]).float(),
#                             torch.tensor(target[train_size:]).long())
    return train_ds, val_ds #, test_ds

# %%
def build_loaders(data, batch_size = 128, jobs = 8):
#     train_ds, valid_ds, test_ds = data
    train_ds, valid_ds = data
    train_dl = DataLoader(train_ds, batch_size = batch_size, shuffle = False, num_workers = jobs)
    valid_dl = DataLoader(valid_ds, batch_size = batch_size, shuffle = False, num_workers = jobs)
#     test_dl = DataLoader(test_ds, batch_size = batch_size, shuffle = True, num_workers = jobs)
    return train_dl, valid_dl #, test_dl

# %%
class _SepConv1d(nn.Module):
    """A simple separable convolution implementation.
    
    The separable convlution is a method to reduce number of the parameters 
    in the deep learning network for slight decrease in predictions quality.
    """
    def __init__(self, ni, no, kernel, stride, pad):
        super().__init__()
        self.depthwise = nn.Conv1d(ni, ni, kernel, stride, padding=pad, groups=ni)
        self.pointwise = nn.Conv1d(ni, no, kernel_size=1)

    def forward(self, x):
        return self.pointwise(self.depthwise(x))

# %%
class SepConv1d(nn.Module):
    """Implementes a 1-d convolution with 'batteries included'.
    
    The module adds (optionally) activation function and dropout layers right after
    a separable convolution layer.
    """
    def __init__(self, ni, no, kernel, stride, pad, drop=None,
                 activ=lambda: nn.ReLU(inplace=True)):
    
        super().__init__()
        assert drop is None or (0.0 < drop < 1.0)
        layers = [_SepConv1d(ni, no, kernel, stride, pad)]
        if activ:
            layers.append(activ())
        if drop is not None:
            layers.append(nn.Dropout(drop))
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x): 
        return self.layers(x)

# %%
class Flatten(nn.Module):
    """Converts N-dimensional tensor into 'flat' one."""

    def __init__(self, keep_batch_dim=True):
        super().__init__()
        self.keep_batch_dim = keep_batch_dim

    def forward(self, x):
        if self.keep_batch_dim:
            return x.view(x.size(0), -1)
        return x.view(-1)

# %%
class PrintSize(nn.Module):
    def __init__(self):
        super(PrintSize, self).__init__()
        
    def forward(self, x):
        print(x.shape)
        return x

# %%
class Classifier(nn.Module):
    def __init__(self, raw_ni, fft_ni, no, drop=.5):
        super().__init__()
        #PKS [[4,8,2],[3,8,2],[5,8,2],[2,8,2]]
        self.raw = nn.Sequential( #kernel, stride, pad
            SepConv1d(raw_ni,  32, 8, 2, 4, drop=drop),
            SepConv1d(    32,  64, 8, 2, 3, drop=drop),
            SepConv1d(    64, 128, 8, 2, 5, drop=drop),
            SepConv1d(   128, 256, 8, 2, 2, drop=drop),
            Flatten(),
#             PrintSize(),
            nn.Dropout(drop), nn.Linear(512, 256), nn.ReLU(inplace=True),
            nn.Dropout(drop), nn.Linear( 256, 64), nn.ReLU(inplace=True))
        #PKS [3,8,2],[5,8,2],[4,8,2],[5,8,2],[3,8,2]
        self.fft = nn.Sequential(
            SepConv1d(fft_ni,  32, 8, 2, 3, drop=drop),
            SepConv1d(    32,  64, 8, 2, 5, drop=drop),
            SepConv1d(    64, 128, 8, 2, 4, drop=drop),
            SepConv1d(   128, 128, 8, 2, 5, drop=drop),
            SepConv1d(   128, 256, 8, 2, 3, drop=drop),
            Flatten(),
#             PrintSize(),
            nn.Dropout(drop), nn.Linear(512, 256), nn.ReLU(inplace=True),
            nn.Dropout(drop), nn.Linear( 256, 64), nn.ReLU(inplace=True))
        
        self.out = nn.Sequential(
            nn.Linear(128, 64), nn.ReLU(inplace=True), nn.Linear(64, no))
        
    def forward(self, t_raw, t_fft):
        raw_out = self.raw(t_raw)
        fft_out = self.fft(t_fft)
        t_in = torch.cat([raw_out, fft_out], dim=1)
        out = self.out(t_in)
        return out

# %%
seed = 1
train_size = len(x_train)
datasets = build_datasets((x_train, x_train_fft), y_train_transformed,
                          train_size = train_size, valid_pct = 0.1, seed=seed)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')

# %%
raw_feat = x_train.shape[1]
fft_feat = x_train_fft.shape[1]
# trn_dl, val_dl, tst_dl = build_loaders(datasets, batch_size=256)
trn_dl, val_dl = build_loaders(datasets, batch_size=512)

lr = 0.0002
n_epochs = 2000
iterations_per_epoch = len(trn_dl)
num_classes = 20
best_acc = 0
best_f1 = 0
patience, trials = 1000, 0
base = 1
step = 2
loss_history = []
acc_history = []
gstep = -1
model = Classifier(raw_feat, fft_feat, num_classes,drop = .5).to(device)
criterion = nn.CrossEntropyLoss(reduction='sum')
opt = torch.optim.Adam(model.parameters(), lr=lr, weight_decay= 0.0001)
lr_scheduler = torch.optim.lr_scheduler.OneCycleLR(opt, 0.004, steps_per_epoch = len(datasets[0]),epochs = n_epochs,
                                                  pct_start = 0.4,base_momentum = 0.85, max_momentum=0.95,
                                                  div_factor = 10.0, last_epoch = gstep)
print('Start model training')

for epoch in range(1, n_epochs + 1):
    
    model.train()
    epoch_loss = 0
    for i, batch in enumerate(trn_dl):
        
        x_raw, x_fft, y_batch = [t.to(device) for t in batch]
        opt.zero_grad()
        out = model(x_raw, x_fft)
        loss = criterion(out, y_batch)
        epoch_loss += loss.item()
        loss.backward()
        opt.step()
        lr_scheduler.step()
        
    epoch_loss /= train_size
    loss_history.append(epoch_loss)
    
    model.eval()
    correct, total, epoch_f1 = 0, 0, []
    for batch in val_dl:
        x_raw, x_fft, y_batch = [t.to(device) for t in batch]
        out = model(x_raw, x_fft)
        preds = F.log_softmax(out, dim=1).argmax(dim=1)
#         print(f"preds: {preds} \n y {y_batch} \n F_1 {f1_score(y_batch, preds,average="macro")}")
        batch_f1 = f1_score(y_batch.detach().cpu().clone().numpy(), preds.detach().cpu().clone().numpy(), 
                           average="macro")
        epoch_f1.append(batch_f1)
        total += y_batch.size(0)
        correct += (preds == y_batch).sum().item()
    cur_f1 = np.mean(epoch_f1)
    print(f"Epoch {epoch}: mean f1_score: {cur_f1}")
    epoch_f1 = []
    
    
    acc = correct / total
    acc_history.append(acc)

    if epoch % base == 0:
        print(f'Epoch: {epoch:3d}. Loss: {epoch_loss:.4f}. Acc.: {acc:2.2%}')
        base *= step

    if acc > best_acc:
        trials = 0
        best_acc = acc
        torch.save(model.state_dict(), 'bestaccu.pth')
        print(f'Epoch {epoch} best model saved with accuracy: {best_acc:2.2%}')
    if cur_f1 > best_f1:
        trials = 0
        best_f1 = cur_f1
        torch.save(model.state_dict(), 'bestf1.pth')
        print(f'Epoch {epoch} best F1 saved with F1: {best_f1:2.2%}')
    else:
        trials += 1
        if trials >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
            
print('Done!')
# Out:
# Start model training
# Epoch 1: mean f1_score: 0.4939504120388609
# Epoch:   1. Loss: 0.1685. Acc.: 72.36%
# Epoch 1 best model saved with accuracy: 72.36%
# Epoch 2: mean f1_score: 0.4939504120388609
# Epoch:   2. Loss: 0.1022. Acc.: 72.36%
# Epoch 3: mean f1_score: 0.4939504120388609
# Epoch 4: mean f1_score: 0.5043196975387959
# Epoch:   4. Loss: 0.1007. Acc.: 73.13%
# Epoch 4 best model saved with accuracy: 73.13%
# Epoch 5: mean f1_score: 0.5264430401810569
# Epoch 5 best model saved with accuracy: 75.09%
# Epoch 6: mean f1_score: 0.6500675753041322
# Epoch 6 best model saved with accuracy: 86.43%
# Epoch 7: mean f1_score: 0.6597496399437858
# Epoch 7 best model saved with accuracy: 90.75%
# Epoch 8: mean f1_score: 0.6348621813517372
# Epoch:   8. Loss: 0.0455. Acc.: 90.30%
# Epoch 9: mean f1_score: 0.6360624174134567
# Epoch 10: mean f1_score: 0.6336001889112323
# Epoch 11: mean f1_score: 0.637726243707626
# Epoch 11 best model saved with accuracy: 90.76%
# Epoch 12: mean f1_score: 0.6384843048673213
# Epoch 12 best model saved with accuracy: 90.85%
# Epoch 13: mean f1_score: 0.6354967303971812
# Epoch 13 best model saved with accuracy: 90.87%
# Epoch 14: mean f1_score: 0.6436741838689125
# Epoch 14 best model saved with accuracy: 91.05%
# Epoch 15: mean f1_score: 0.6419910899927563
# Epoch 15 best model saved with accuracy: 91.06%
# Epoch 16: mean f1_score: 0.643885356701155
# Epoch:  16. Loss: 0.0361. Acc.: 91.19%
# Epoch 16 best model saved with accuracy: 91.19%
# Epoch 17: mean f1_score: 0.6452342980451742
# Epoch 17 best model saved with accuracy: 91.26%
# Epoch 18: mean f1_score: 0.6445226749902315
# Epoch 18 best model saved with accuracy: 91.27%
# Epoch 19: mean f1_score: 0.6431243046394871
# Epoch 19 best model saved with accuracy: 91.31%
# Epoch 20: mean f1_score: 0.6415842904760896
# Epoch 21: mean f1_score: 0.6454200920389
# Epoch 21 best model saved with accuracy: 91.48%
# Epoch 22: mean f1_score: 0.6450752743719342
# Epoch 23: mean f1_score: 0.6425924787615319
# Epoch 24: mean f1_score: 0.6427763262595225
# Epoch 25: mean f1_score: 0.6428659481763735
# Epoch 26: mean f1_score: 0.6446732101424497
# Epoch 26 best model saved with accuracy: 91.50%
# Epoch 27: mean f1_score: 0.6446782805069622
# Epoch 28: mean f1_score: 0.6480854225385394
# Epoch 28 best model saved with accuracy: 91.56%
# Epoch 29: mean f1_score: 0.6455576081607849
# Epoch 30: mean f1_score: 0.6456316271219589
# Epoch 31: mean f1_score: 0.6512295108973304
# Epoch 31 best model saved with accuracy: 91.64%
# Epoch 32: mean f1_score: 0.6519890288949114
# Epoch:  32. Loss: 0.0322. Acc.: 91.67%
# Epoch 32 best model saved with accuracy: 91.67%
# Epoch 33: mean f1_score: 0.6486988157551545
# Epoch 34: mean f1_score: 0.6525656093467576
# Epoch 35: mean f1_score: 0.6531846845743282
# Epoch 36: mean f1_score: 0.6513481283693161
# Epoch 37: mean f1_score: 0.6523942244103967
# Epoch 38: mean f1_score: 0.6535014173830858
# Epoch 39: mean f1_score: 0.655665106132263
# Epoch 39 best model saved with accuracy: 91.69%
# Epoch 40: mean f1_score: 0.6551869648118678
# Epoch 41: mean f1_score: 0.6553164829152746
# Epoch 41 best model saved with accuracy: 91.69%
# Epoch 42: mean f1_score: 0.6575317261141773
# Epoch 43: mean f1_score: 0.6571090398405489
# Epoch 43 best model saved with accuracy: 91.70%
# Epoch 44: mean f1_score: 0.6576311058114954
# Epoch 45: mean f1_score: 0.6593534542668271
# Epoch 46: mean f1_score: 0.657996525863096
# Epoch 47: mean f1_score: 0.6614374488561597
# Epoch 47 best model saved with accuracy: 91.72%
# Epoch 48: mean f1_score: 0.6626546055792709
# Epoch 48 best model saved with accuracy: 91.82%
# Epoch 49: mean f1_score: 0.6633683532054003
# Epoch 50: mean f1_score: 0.6656298478815901
# Epoch 50 best model saved with accuracy: 91.93%
# Epoch 51: mean f1_score: 0.663553892253019
# Epoch 52: mean f1_score: 0.6654916766891428
# Epoch 53: mean f1_score: 0.666729950934556
# Epoch 54: mean f1_score: 0.6648692684718023
# Epoch 55: mean f1_score: 0.6647882588864569
# Epoch 56: mean f1_score: 0.6629791833001146
# Epoch 57: mean f1_score: 0.6636304641068164
# Epoch 58: mean f1_score: 0.6665406576118748
# Epoch 59: mean f1_score: 0.6655197603144452
# Epoch 60: mean f1_score: 0.6653077441352697
# Epoch 61: mean f1_score: 0.6628433348960421
# Epoch 62: mean f1_score: 0.6618238676598542
# Epoch 63: mean f1_score: 0.6643378557148882
# Epoch 64: mean f1_score: 0.6637588029040963
# Epoch:  64. Loss: 0.0280. Acc.: 91.86%
# Epoch 65: mean f1_score: 0.6632943147870335
# Epoch 66: mean f1_score: 0.6650307504455462
# Epoch 67: mean f1_score: 0.6624564659972522
# Epoch 68: mean f1_score: 0.663675210412864
# Epoch 69: mean f1_score: 0.6677464426167244
# Epoch 70: mean f1_score: 0.6664269268538867
# Epoch 71: mean f1_score: 0.6660964655169358
# Epoch 72: mean f1_score: 0.664812956416633
# Epoch 72 best model saved with accuracy: 91.94%
# Epoch 73: mean f1_score: 0.665139554409225
# Epoch 74: mean f1_score: 0.6646847529617679
# Epoch 75: mean f1_score: 0.6639250504242606
# Epoch 76: mean f1_score: 0.6602424403471886
# Epoch 77: mean f1_score: 0.6616046278345569
# Epoch 78: mean f1_score: 0.6612006751013134
# Epoch 79: mean f1_score: 0.6579640016452427
# Epoch 80: mean f1_score: 0.6628337126375229
# Epoch 81: mean f1_score: 0.6622832485311904
# Epoch 82: mean f1_score: 0.6572600365468463
# Epoch 83: mean f1_score: 0.6642550860747769
# Epoch 83 best model saved with accuracy: 92.02%
# Epoch 84: mean f1_score: 0.6588325352015137
# Epoch 85: mean f1_score: 0.6592818144344568
# Epoch 86: mean f1_score: 0.6606193612216725
# Epoch 87: mean f1_score: 0.6555140110418465
# Epoch 88: mean f1_score: 0.6554458892561331
# Epoch 89: mean f1_score: 0.6555447296126871
# Epoch 90: mean f1_score: 0.6573436783354762
# Epoch 91: mean f1_score: 0.6599148357247135
# Epoch 92: mean f1_score: 0.657847069721462
# Epoch 93: mean f1_score: 0.653830325403523
# Epoch 94: mean f1_score: 0.6554761666145681
# Epoch 95: mean f1_score: 0.6578564696241155
# Epoch 96: mean f1_score: 0.6572379510527399
# Epoch 97: mean f1_score: 0.6580520359384933
# Epoch 98: mean f1_score: 0.6569051218080876
# Epoch 99: mean f1_score: 0.6574261720603328
# Epoch 100: mean f1_score: 0.6558439341135589
# Epoch 101: mean f1_score: 0.658909000448871
# Epoch 102: mean f1_score: 0.6590666894228325
# Epoch 103: mean f1_score: 0.6548005440568027
# Epoch 104: mean f1_score: 0.658219443352802
# Epoch 105: mean f1_score: 0.6586928065500904
# Epoch 106: mean f1_score: 0.6580925297073431
# Epoch 107: mean f1_score: 0.6565488729368817
# Epoch 108: mean f1_score: 0.6579036466477722
# Epoch 109: mean f1_score: 0.6594341983882561
# Epoch 110: mean f1_score: 0.6578172802148392
# Epoch 111: mean f1_score: 0.6589731726275319
# Epoch 112: mean f1_score: 0.6604775269337404
# Epoch 113: mean f1_score: 0.658443227197344
# Epoch 114: mean f1_score: 0.6591197087267346
# Epoch 115: mean f1_score: 0.6580686337442014
# Epoch 116: mean f1_score: 0.6583529795881176
# Epoch 117: mean f1_score: 0.6563495746346395
# Epoch 117 best model saved with accuracy: 92.04%
# Epoch 118: mean f1_score: 0.656597983593951
# Epoch 119: mean f1_score: 0.6587739195101204
# Epoch 120: mean f1_score: 0.6609248476782741
# Epoch 121: mean f1_score: 0.6562983302734168
# Epoch 122: mean f1_score: 0.6547674935751769
# Epoch 123: mean f1_score: 0.6559198198405528
# Epoch 124: mean f1_score: 0.6588279726774485
# Epoch 125: mean f1_score: 0.6600376974337594
# Epoch 126: mean f1_score: 0.6623656965639799
# Epoch 127: mean f1_score: 0.6591621594656103
# Epoch 127 best model saved with accuracy: 92.06%
# Epoch 128: mean f1_score: 0.6603707681906409
# Epoch: 128. Loss: 0.0248. Acc.: 92.03%
# Epoch 129: mean f1_score: 0.6574189667654375
# Epoch 130: mean f1_score: 0.6644575230056553
# Epoch 130 best model saved with accuracy: 92.08%
# Epoch 131: mean f1_score: 0.6634138961445992
# Epoch 131 best model saved with accuracy: 92.10%
# Epoch 132: mean f1_score: 0.6638238685188387
# Epoch 132 best model saved with accuracy: 92.12%
# Epoch 133: mean f1_score: 0.6583214043455399
# Epoch 134: mean f1_score: 0.660144129202741
# Epoch 135: mean f1_score: 0.6599857356544463
# Epoch 135 best model saved with accuracy: 92.14%
# Epoch 136: mean f1_score: 0.660291352312514
# Epoch 136 best model saved with accuracy: 92.15%
# Epoch 137: mean f1_score: 0.6612329693665397
# Epoch 138: mean f1_score: 0.6607234113814185
# Epoch 139: mean f1_score: 0.6598420759403404
# Epoch 140: mean f1_score: 0.6583542045353048
# Epoch 141: mean f1_score: 0.659976840293429
# Epoch 141 best model saved with accuracy: 92.18%
# Epoch 142: mean f1_score: 0.6634058577952912
# Epoch 143: mean f1_score: 0.6632140325430371
# Epoch 144: mean f1_score: 0.659807790604728
# Epoch 145: mean f1_score: 0.6604540933173878
# Epoch 146: mean f1_score: 0.6600206144474918
# Epoch 147: mean f1_score: 0.6612802184701613
# Epoch 148: mean f1_score: 0.6589706998530345
# Epoch 149: mean f1_score: 0.6602892084426083
# Epoch 150: mean f1_score: 0.6584726628797919
# Epoch 151: mean f1_score: 0.6591552504393273
# Epoch 152: mean f1_score: 0.6592274598703407
# Epoch 153: mean f1_score: 0.6600775076162834
# Epoch 154: mean f1_score: 0.6595902777178844
# Epoch 155: mean f1_score: 0.6590291640379984
# Epoch 156: mean f1_score: 0.6604717899892479
# Epoch 157: mean f1_score: 0.6583239630504948
# Epoch 158: mean f1_score: 0.6579919801172698
# Epoch 159: mean f1_score: 0.6554317529823974
# Epoch 160: mean f1_score: 0.6582437100721814
# Epoch 161: mean f1_score: 0.6570127981153392
# Epoch 162: mean f1_score: 0.6567797815147166
# Epoch 163: mean f1_score: 0.6581883405905663
# Epoch 164: mean f1_score: 0.6568159340203849
# Epoch 165: mean f1_score: 0.6575232290675206
# Epoch 166: mean f1_score: 0.6581030146296635
# Epoch 167: mean f1_score: 0.6588271519403363
# Epoch 168: mean f1_score: 0.6568781814388055
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-f261e55e2a20> in <module>
#      45     for batch in val_dl:
#      46         x_raw, x_fft, y_batch = [t.to(device) for t in batch]
# ---> 47         out = model(x_raw, x_fft)
#      48         preds = F.log_softmax(out, dim=1).argmax(dim=1)
#      49 #         print(f"preds: {preds} \n y {y_batch} \n F_1 {f1_score(y_batch, preds,average="macro")}")
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-25-403a1f914d73> in forward(self, t_raw, t_fft)
#      28
#      29     def forward(self, t_raw, t_fft):
# ---> 30         raw_out = self.raw(t_raw)
#      31         fft_out = self.fft(t_fft)
#      32         t_in = torch.cat([raw_out, fft_out], dim=1)
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-22-8c1b61753b0e> in forward(self, x)
#      18
#      19     def forward(self, x):
# ---> 20         return self.layers(x)
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/modules/activation.py in forward(self, input)
#     100
#     101     def forward(self, input: Tensor) -> Tensor:
# --> 102         return F.relu(input, inplace=self.inplace)
#     103
#     104     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/torch/nn/functional.py in relu(input, inplace)
#    1132             return handle_torch_function(relu, (input,), input, inplace=inplace)
#    1133     if inplace:
# -> 1134         result = torch.relu_(input)
#    1135     else:
#    1136         result = torch.relu(input)
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), 'latest.pth')

# %% [markdown]
# # Inference

# %%
del x_train,x_train_fft,x_train_rolled
model = Classifier(10, 10, 20)
model.load_state_dict(torch.load("./best.pth"))
model.eval()
# Out:
# Classifier(
#   (raw): Sequential(
#     (0): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(10, 10, kernel_size=(8,), stride=(2,), padding=(4,), groups=10)
#           (pointwise): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(32, 32, kernel_size=(8,), stride=(2,), padding=(3,), groups=32)
#           (pointwise): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (2): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(64, 64, kernel_size=(8,), stride=(2,), padding=(5,), groups=64)
#           (pointwise): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (3): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(2,), groups=128)
#           (pointwise): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (4): Flatten()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=256, out_features=64, bias=True)
#     (10): ReLU(inplace=True)
#   )
#   (fft): Sequential(
#     (0): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(10, 10, kernel_size=(8,), stride=(2,), padding=(3,), groups=10)
#           (pointwise): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(32, 32, kernel_size=(8,), stride=(2,), padding=(5,), groups=32)
#           (pointwise): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (2): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(64, 64, kernel_size=(8,), stride=(2,), padding=(4,), groups=64)
#           (pointwise): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (3): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(5,), groups=128)
#           (pointwise): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (4): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(3,), groups=128)
#           (pointwise): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (5): Flatten()
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=512, out_features=256, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Dropout(p=0.5, inplace=False)
#     (10): Linear(in_features=256, out_features=64, bias=True)
#     (11): ReLU(inplace=True)
#   )
#   (out): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=64, out_features=20, bias=True)
#   )
# )

# %%
x_test = pd.read_csv("../FIT5149_A2_data/test_data_nolabels.csv")
x_test.rename(columns={'Unnamed: 0': 'id'}, inplace= 1)
x_test['id'] = x_test['id'] + 28
x_test
# Out:
#             id   load  hourofday dayofweek    dif  absdif    max       var  \
# 0           29  1.869          0       Mon  0.000   0.000  0.000  0.000000
# 1           30  1.673          0       Mon -0.196   0.196  0.000  0.000000
# 2           31  1.660          0       Mon -0.013   0.013  0.000  0.000000
# 3           32  1.772          0       Mon  0.112   0.112  0.000  0.000000
# 4           33  1.679          0       Mon -0.093   0.093  0.000  0.000000
# ...        ...    ...        ...       ...    ...     ...    ...       ...
# 105535  105564  1.076         23       Sat -0.001   0.001  6.204  2.484129
# 105536  105565  1.019         23       Sat -0.057   0.057  6.215  2.614626
# 105537  105566  1.014         23       Sat -0.005   0.005  6.215  2.729923
# 105538  105567  1.011         23       Sat -0.003   0.003  6.215  2.868153
# 105539  105568  1.258         23       Sat  0.247   0.247  6.215  2.972294
#
#          entropy  nonlinear     hurst
# 0       0.000000   0.000000  0.000000
# 1       0.000000   0.000000  0.000000
# 2       0.000000   0.000000  0.000000
# 3       0.000000   0.000000  0.000000
# 4       0.000000   0.000000  0.000000
# ...          ...        ...       ...
# 105535  0.592658   0.042413  0.990185
# 105536  0.601761   0.038118  0.990529
# 105537  0.629122   0.048229  0.993554
# 105538  0.658328   0.046729  0.993813
# 105539  0.676443   0.049666  0.993965
#
# [105540 rows x 11 columns]

# %%
scale_list = ['absdif', 'dayofweek', 'dif', 'entropy', 'hourofday', 'hurst', 'load', 'max', 'nonlinear', 'var']
x_test['dayofweek'] = le.transform(x_test['dayofweek'])
x_test[scale_list] = scaler.transform(x_test[scale_list])
x_test
# Out:
#             id      load  hourofday  dayofweek       dif    absdif       max  \
# 0           29 -0.166969  -1.659524  -1.006070  0.000001 -0.315136 -1.866220
# 1           30 -0.270641  -1.659524  -1.006070 -0.369164  0.071926 -1.866220
# 2           31 -0.277518  -1.659524  -1.006070 -0.024484 -0.289464 -1.866220
# 3           32 -0.218276  -1.659524  -1.006070  0.210953 -0.093958 -1.866220
# 4           33 -0.267468  -1.659524  -1.006070 -0.175164 -0.131479 -1.866220
# ...        ...       ...        ...        ...       ...       ...       ...
# 105535  105564 -0.586420   1.664007  -0.506444 -0.001882 -0.313161  1.044964
# 105536  105565 -0.616570   1.664007  -0.506444 -0.107358 -0.202572  1.050126
# 105537  105566 -0.619215   1.664007  -0.506444 -0.009416 -0.305262  1.050126
# 105538  105567 -0.620802   1.664007  -0.506444 -0.005649 -0.309212  1.050126
# 105539  105568 -0.490153   1.664007  -0.506444  0.465225  0.172641  1.050126
#
#              var   entropy  nonlinear      hurst
# 0      -1.046775 -7.500160  -0.562601 -14.864864
# 1      -1.046775 -7.500160  -0.562601 -14.864864
# 2      -1.046775 -7.500160  -0.562601 -14.864864
# 3      -1.046775 -7.500160  -0.562601 -14.864864
# 4      -1.046775 -7.500160  -0.562601 -14.864864
# ...          ...       ...        ...        ...
# 105535  0.342846 -1.219789  -0.546356   0.266524
# 105536  0.415846 -1.123327  -0.548001   0.271783
# 105537  0.480343 -0.833378  -0.544128   0.317999
# 105538  0.557669 -0.523885  -0.544702   0.321967
# 105539  0.615926 -0.331925  -0.543578   0.324291
#
# [105540 rows x 11 columns]

# %%
extra_len = pd.DataFrame(x_test.iloc[0:1,:].values.repeat(29, axis = 0), columns=x_test.columns)
extra_len['id'] = list(range(0,29))
x_test = pd.concat([extra_len, x_test])
x_test['dummy_id'] = 1
x_test.reset_index(drop= True, inplace=True)
x_test.head(100)
# Out:
#     id      load  hourofday  dayofweek       dif    absdif       max  \
# 0    0 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 1    1 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 2    2 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 3    3 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 4    4 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 5    5 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 6    6 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 7    7 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 8    8 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 9    9 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 10  10 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 11  11 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 12  12 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 13  13 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 14  14 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 15  15 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 16  16 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 17  17 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 18  18 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 19  19 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 20  20 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 21  21 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 22  22 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 23  23 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 24  24 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 25  25 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 26  26 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 27  27 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 28  28 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 29  29 -0.166969  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 30  30 -0.270641  -1.659524   -1.00607 -0.369164  0.071926 -1.866220
# 31  31 -0.277518  -1.659524   -1.00607 -0.024484 -0.289464 -1.866220
# 32  32 -0.218276  -1.659524   -1.00607  0.210953 -0.093958 -1.866220
# 33  33 -0.267468  -1.659524   -1.00607 -0.175164 -0.131479 -1.866220
# 34  34 -0.216689  -1.659524   -1.00607  0.180817 -0.125554 -1.866220
# 35  35 -0.225152  -1.659524   -1.00607 -0.030135 -0.283539 -1.866220
# 36  36 -0.253715  -1.659524   -1.00607 -0.101707 -0.208496 -1.866220
# 37  37 -0.188126  -1.659524   -1.00607  0.233555 -0.070260 -1.866220
# 38  38 -0.245781  -1.659524   -1.00607 -0.205300 -0.099882 -1.866220
# 39  39 -0.269055  -1.659524   -1.00607 -0.082872 -0.228244 -1.866220
# 40  40 -0.218276  -1.659524   -1.00607  0.180817 -0.125554 -1.866220
# 41  41 -0.284923  -1.659524   -1.00607 -0.237319 -0.066310 -1.866220
# 42  42 -0.284923  -1.659524   -1.00607  0.000001 -0.315136 -1.866220
# 43  43  0.448721  -1.659524   -1.00607  2.612409  2.423922 -1.866220
# 44  44  0.400587  -1.659524   -1.00607 -0.171397 -0.135429 -1.866220
# 45  45  0.399530  -1.659524   -1.00607 -0.003766 -0.311186 -1.866220
# 46  46  0.464590  -1.659524   -1.00607  0.231671 -0.072235 -1.866220
# 47  47  0.345048  -1.659524   -1.00607 -0.425669  0.131170 -1.866220
# 48  48  0.376256  -1.659524   -1.00607  0.111128 -0.198622 -1.866220
# 49  49  0.365148  -1.659524   -1.00607 -0.039552 -0.273665 -1.866220
# 50  50  0.337643  -1.659524   -1.00607 -0.097940 -0.212446 -1.866220
# 51  51  0.404290  -1.659524   -1.00607  0.237322 -0.066310 -1.866220
# 52  52  0.347164  -1.659524   -1.00607 -0.203416 -0.101857 -1.866220
# 53  53  0.286336  -1.659524   -1.00607 -0.216601 -0.088033 -1.866220
# 54  54  0.303791  -1.659524   -1.00607  0.062157 -0.249967 -1.866220
# 55  55  0.374140  -1.659524   -1.00607  0.250506 -0.052487 -1.866220
# 56  56  0.379430  -1.659524   -1.00607  0.018836 -0.295388 -1.866220
# 57  57  0.461416  -1.659524   -1.00607  0.291943 -0.009041 -1.866220
# 58  58  0.414869  -1.659524   -1.00607 -0.165746 -0.141353 -1.866220
# 59  59  0.428092  -1.659524   -1.00607  0.047089 -0.265766 -0.389043
# 60  60  0.445548  -1.659524   -1.00607  0.062157 -0.249967 -0.389043
# 61  61  0.446077  -1.659524   -1.00607  0.001885 -0.313161 -0.389043
# 62  62  0.447134  -1.659524   -1.00607  0.003768 -0.311186 -0.389043
# 63  63  0.509550  -1.659524   -1.00607  0.222254 -0.082109 -0.389043
# 64  64  0.441316  -1.659524   -1.00607 -0.242970 -0.060386 -0.389043
# 65  65  0.433911  -1.659524   -1.00607 -0.026368 -0.287489 -0.389043
# 66  66  0.424919  -1.659524   -1.00607 -0.032018 -0.281564 -0.389043
# 67  67  0.496326  -1.659524   -1.00607  0.254273 -0.048537 -0.389043
# 68  68  0.430737  -1.659524   -1.00607 -0.233552 -0.070260 -0.389043
# 69  69  0.429679  -1.659524   -1.00607 -0.003766 -0.311186 -0.389043
# 70  70  0.452424  -1.659524   -1.00607  0.080992 -0.230219 -0.389043
# 71  71  0.471995  -1.659524   -1.00607  0.069691 -0.242068 -0.389043
# 72  72  0.420687  -1.659524   -1.00607 -0.182698 -0.123580 -0.389043
# 73  73  0.423861  -1.659524   -1.00607  0.011302 -0.303287 -0.389043
# 74  74  0.425448  -1.659524   -1.00607  0.005652 -0.309212 -0.389043
# 75  75  0.451366  -1.659524   -1.00607  0.092293 -0.218370 -0.389043
# 76  76 -0.232557  -1.659524   -1.00607 -2.435358  2.238290 -0.389043
# 77  77 -0.257947  -1.659524   -1.00607 -0.090406 -0.220345 -0.389043
# 78  78 -0.275931  -1.659524   -1.00607 -0.064038 -0.247993 -0.389043
# 79  79 -0.344164  -1.659524   -1.00607 -0.242970 -0.060386 -0.389043
# 80  80 -0.282807  -1.659524   -1.00607  0.218487 -0.086058 -0.389043
# 81  81 -0.348396  -1.659524   -1.00607 -0.233552 -0.070260 -0.389043
# 82  82 -0.340991  -1.659524   -1.00607  0.026370 -0.287489 -0.389043
# 83  83 -0.337817  -1.659524   -1.00607  0.011302 -0.303287 -0.389043
# 84  84 -0.336230  -1.659524   -1.00607  0.005652 -0.309212 -0.389043
# 85  85 -0.269584  -1.659524   -1.00607  0.237322 -0.066310 -0.389043
# 86  86 -0.336759  -1.659524   -1.00607 -0.239203 -0.064335 -0.389043
# 87  87 -0.337288  -1.659524   -1.00607 -0.001882 -0.313161 -0.389043
# 88  88 -0.336759  -1.515023   -1.00607  0.001885 -0.313161 -0.389043
# 89  89 -0.312957  -1.515023   -1.00607  0.084759 -0.226270 -0.389043
# 90  90 -0.310841  -1.515023   -1.00607  0.007535 -0.307237 -0.389043
# 91  91 -0.223565  -1.515023   -1.00607  0.310778  0.010707 -0.389043
# 92  92 -0.265881  -1.515023   -1.00607 -0.150678 -0.157151 -0.389043
# 93  93 -0.257947  -1.515023   -1.00607  0.028254 -0.285514 -0.389043
# 94  94 -0.368496  -1.515023   -1.00607 -0.393649  0.097599 -0.400774
# 95  95 -0.388067  -1.515023   -1.00607 -0.069688 -0.242068 -0.400774
# 96  96 -0.396001  -1.515023   -1.00607 -0.028251 -0.285514 -0.400774
# 97  97 -0.401290  -1.515023   -1.00607 -0.018834 -0.295388 -0.400774
# 98  98 -0.402348  -1.515023   -1.00607 -0.003766 -0.311186 -0.422359
# 99  99 -0.402877  -1.515023   -1.00607 -0.001882 -0.313161 -0.422359
#
#          var   entropy  nonlinear      hurst  dummy_id
# 0  -1.046775 -7.500160  -0.562601 -14.864864         1
# 1  -1.046775 -7.500160  -0.562601 -14.864864         1
# 2  -1.046775 -7.500160  -0.562601 -14.864864         1
# 3  -1.046775 -7.500160  -0.562601 -14.864864         1
# 4  -1.046775 -7.500160  -0.562601 -14.864864         1
# 5  -1.046775 -7.500160  -0.562601 -14.864864         1
# 6  -1.046775 -7.500160  -0.562601 -14.864864         1
# 7  -1.046775 -7.500160  -0.562601 -14.864864         1
# 8  -1.046775 -7.500160  -0.562601 -14.864864         1
# 9  -1.046775 -7.500160  -0.562601 -14.864864         1
# 10 -1.046775 -7.500160  -0.562601 -14.864864         1
# 11 -1.046775 -7.500160  -0.562601 -14.864864         1
# 12 -1.046775 -7.500160  -0.562601 -14.864864         1
# 13 -1.046775 -7.500160  -0.562601 -14.864864         1
# 14 -1.046775 -7.500160  -0.562601 -14.864864         1
# 15 -1.046775 -7.500160  -0.562601 -14.864864         1
# 16 -1.046775 -7.500160  -0.562601 -14.864864         1
# 17 -1.046775 -7.500160  -0.562601 -14.864864         1
# 18 -1.046775 -7.500160  -0.562601 -14.864864         1
# 19 -1.046775 -7.500160  -0.562601 -14.864864         1
# 20 -1.046775 -7.500160  -0.562601 -14.864864         1
# 21 -1.046775 -7.500160  -0.562601 -14.864864         1
# 22 -1.046775 -7.500160  -0.562601 -14.864864         1
# 23 -1.046775 -7.500160  -0.562601 -14.864864         1
# 24 -1.046775 -7.500160  -0.562601 -14.864864         1
# 25 -1.046775 -7.500160  -0.562601 -14.864864         1
# 26 -1.046775 -7.500160  -0.562601 -14.864864         1
# 27 -1.046775 -7.500160  -0.562601 -14.864864         1
# 28 -1.046775 -7.500160  -0.562601 -14.864864         1
# 29 -1.046775 -7.500160  -0.562601 -14.864864         1
# 30 -1.046775 -7.500160  -0.562601 -14.864864         1
# 31 -1.046775 -7.500160  -0.562601 -14.864864         1
# 32 -1.046775 -7.500160  -0.562601 -14.864864         1
# 33 -1.046775 -7.500160  -0.562601 -14.864864         1
# 34 -1.046775 -7.500160  -0.562601 -14.864864         1
# 35 -1.046775 -7.500160  -0.562601 -14.864864         1
# 36 -1.046775 -7.500160  -0.562601 -14.864864         1
# 37 -1.046775 -7.500160  -0.562601 -14.864864         1
# 38 -1.046775 -7.500160  -0.562601 -14.864864         1
# 39 -1.046775 -7.500160  -0.562601 -14.864864         1
# 40 -1.046775 -7.500160  -0.562601 -14.864864         1
# 41 -1.046775 -7.500160  -0.562601 -14.864864         1
# 42 -1.046775 -7.500160  -0.562601 -14.864864         1
# 43 -1.046775 -7.500160  -0.562601 -14.864864         1
# 44 -1.046775 -7.500160  -0.562601 -14.864864         1
# 45 -1.046775 -7.500160  -0.562601 -14.864864         1
# 46 -1.046775 -7.500160  -0.562601 -14.864864         1
# 47 -1.046775 -7.500160  -0.562601 -14.864864         1
# 48 -1.046775 -7.500160  -0.562601 -14.864864         1
# 49 -1.046775 -7.500160  -0.562601 -14.864864         1
# 50 -1.046775 -7.500160  -0.562601 -14.864864         1
# 51 -1.046775 -7.500160  -0.562601 -14.864864         1
# 52 -1.046775 -7.500160  -0.562601 -14.864864         1
# 53 -1.046775 -7.500160  -0.562601 -14.864864         1
# 54 -1.046775 -7.500160  -0.562601 -14.864864         1
# 55 -1.046775 -7.500160  -0.562601 -14.864864         1
# 56 -1.046775 -7.500160  -0.562601 -14.864864         1
# 57 -1.046775 -7.500160  -0.562601 -14.864864         1
# 58 -1.046775 -7.500160  -0.562601 -14.864864         1
# 59 -0.800511 -0.122466  -0.393718   0.291557         1
# 60 -0.797297 -0.115879  -0.414300   0.293464         1
# 61 -0.798372 -0.212210  -0.415761   0.291660         1
# 62 -0.798657 -0.355254  -0.404720   0.291530         1
# 63 -0.797774 -0.461259  -0.413023   0.291208         1
# 64 -0.794996 -0.472237  -0.397645   0.290508         1
# 65 -0.790486 -0.403708  -0.418351   0.291341         1
# 66 -0.785929 -0.323383  -0.434631   0.292017         1
# 67 -0.781852 -0.304264  -0.437860   0.292534         1
# 68 -0.776437 -0.392785  -0.438919   0.293115         1
# 69 -0.772193 -0.589044  -0.437973   0.292395         1
# 70 -0.768478 -0.836333  -0.437117   0.291557         1
# 71 -0.763688 -1.044377  -0.424477   0.289758         1
# 72 -0.760322 -1.139702  -0.420977   0.287784         1
# 73 -0.756990 -1.116458  -0.238814   0.333701         1
# 74 -0.754635 -1.035506  -0.244260   0.334068         1
# 75 -0.751882 -0.975362  -0.248780   0.334347         1
# 76 -0.749749 -0.996625  -0.268967   0.334563         1
# 77 -0.750081 -1.114284  -0.302508   0.336019         1
# 78 -0.748053 -1.274862  -0.322958   0.336297         1
# 79 -0.747849 -1.389025  -0.319507   0.336297         1
# 80 -0.748790 -1.385411  -0.303290   0.336115         1
# 81 -0.748229 -1.270088  -0.348272   0.336211         1
# 82 -0.749875 -1.121186  -0.339456   0.336332         1
# 83 -0.750613 -1.021420  -0.285307   0.336550         1
# 84 -0.750403 -1.018697  -0.277570   0.336465         1
# 85 -0.751198 -1.116520  -0.345703   0.337177         1
# 86 -0.754623 -1.264112  -0.349160   0.337053         1
# 87 -0.758916 -1.366416  -0.428306   0.337112         1
# 88 -0.767000 -1.337409  -0.428370   0.336857         1
# 89 -0.769219 -1.176953  -0.476151   0.333563         1
# 90 -0.778424 -0.971653  -0.167561   0.330598         1
# 91 -0.789320 -0.812141  -0.175536   0.328393         1
# 92 -0.800974 -0.746237  -0.182230   0.326762         1
# 93 -0.813533 -0.757148  -0.191777   0.324815         1
# 94 -0.829810 -0.773793  -0.138609   0.322366         1
# 95 -0.843734 -0.702221  -0.147750   0.319398         1
# 96 -0.857935 -0.490137  -0.162954   0.315991         1
# 97 -0.872356 -0.170568  -0.220518   0.312565         1
# 98 -0.890762  0.186447  -0.105376   0.307407         1
# 99 -0.906687  0.522278  -0.131940   0.301416         1

# %%
# x_test_rolled = roll_time_series(x_test, column_id="dummy_id", column_sort="id",
#                             max_timeshift = 29, min_timeshift = 29)
# np.save("../np_x_test_rolled.npy",np.array(x_test_rolled))

x_test_rolled = np.load('../np_x_test_rolled.npy', allow_pickle= True)
x_test_rolled = pd.DataFrame(x_test_rolled, columns=x_test.columns)
x_test_rolled = x_test_rolled[['id', 'load', 'absdif', 'dayofweek', 'dif', 'entropy', 'hourofday', 'hurst', 
        'max', 'nonlinear', 'var','dummy_id']]

# %%
x_test_rolled.head(100)
# Out:
#          id      load    absdif dayofweek       dif  entropy hourofday  \
# 0   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 1   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 2   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 3   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 4   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 5   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 6   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 7   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 8   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 9   (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 10  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 11  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 12  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 13  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 14  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 15  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 16  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 17  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 18  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 19  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 20  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 21  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 22  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 23  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 24  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 25  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 26  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 27  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 28  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 29  (1, 29) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 30  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 31  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 32  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 33  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 34  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 35  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 36  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 37  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 38  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 39  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 40  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 41  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 42  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 43  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 44  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 45  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 46  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 47  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 48  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 49  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 50  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 51  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 52  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 53  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 54  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 55  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 56  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 57  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 58  (1, 30) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 59  (1, 30) -0.270641  0.071926  -1.00607 -0.369164 -7.50016 -1.659524
# 60  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 61  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 62  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 63  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 64  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 65  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 66  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 67  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 68  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 69  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 70  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 71  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 72  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 73  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 74  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 75  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 76  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 77  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 78  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 79  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 80  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 81  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 82  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 83  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 84  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 85  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 86  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 87  (1, 31) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 88  (1, 31) -0.270641  0.071926  -1.00607 -0.369164 -7.50016 -1.659524
# 89  (1, 31) -0.277518 -0.289464  -1.00607 -0.024484 -7.50016 -1.659524
# 90  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 91  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 92  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 93  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 94  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 95  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 96  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 97  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 98  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
# 99  (1, 32) -0.166969 -0.315136  -1.00607  0.000001 -7.50016 -1.659524
#
#         hurst      max nonlinear       var dummy_id
# 0  -14.864864 -1.86622 -0.562601 -1.046775        1
# 1  -14.864864 -1.86622 -0.562601 -1.046775        1
# 2  -14.864864 -1.86622 -0.562601 -1.046775        1
# 3  -14.864864 -1.86622 -0.562601 -1.046775        1
# 4  -14.864864 -1.86622 -0.562601 -1.046775        1
# 5  -14.864864 -1.86622 -0.562601 -1.046775        1
# 6  -14.864864 -1.86622 -0.562601 -1.046775        1
# 7  -14.864864 -1.86622 -0.562601 -1.046775        1
# 8  -14.864864 -1.86622 -0.562601 -1.046775        1
# 9  -14.864864 -1.86622 -0.562601 -1.046775        1
# 10 -14.864864 -1.86622 -0.562601 -1.046775        1
# 11 -14.864864 -1.86622 -0.562601 -1.046775        1
# 12 -14.864864 -1.86622 -0.562601 -1.046775        1
# 13 -14.864864 -1.86622 -0.562601 -1.046775        1
# 14 -14.864864 -1.86622 -0.562601 -1.046775        1
# 15 -14.864864 -1.86622 -0.562601 -1.046775        1
# 16 -14.864864 -1.86622 -0.562601 -1.046775        1
# 17 -14.864864 -1.86622 -0.562601 -1.046775        1
# 18 -14.864864 -1.86622 -0.562601 -1.046775        1
# 19 -14.864864 -1.86622 -0.562601 -1.046775        1
# 20 -14.864864 -1.86622 -0.562601 -1.046775        1
# 21 -14.864864 -1.86622 -0.562601 -1.046775        1
# 22 -14.864864 -1.86622 -0.562601 -1.046775        1
# 23 -14.864864 -1.86622 -0.562601 -1.046775        1
# 24 -14.864864 -1.86622 -0.562601 -1.046775        1
# 25 -14.864864 -1.86622 -0.562601 -1.046775        1
# 26 -14.864864 -1.86622 -0.562601 -1.046775        1
# 27 -14.864864 -1.86622 -0.562601 -1.046775        1
# 28 -14.864864 -1.86622 -0.562601 -1.046775        1
# 29 -14.864864 -1.86622 -0.562601 -1.046775        1
# 30 -14.864864 -1.86622 -0.562601 -1.046775        1
# 31 -14.864864 -1.86622 -0.562601 -1.046775        1
# 32 -14.864864 -1.86622 -0.562601 -1.046775        1
# 33 -14.864864 -1.86622 -0.562601 -1.046775        1
# 34 -14.864864 -1.86622 -0.562601 -1.046775        1
# 35 -14.864864 -1.86622 -0.562601 -1.046775        1
# 36 -14.864864 -1.86622 -0.562601 -1.046775        1
# 37 -14.864864 -1.86622 -0.562601 -1.046775        1
# 38 -14.864864 -1.86622 -0.562601 -1.046775        1
# 39 -14.864864 -1.86622 -0.562601 -1.046775        1
# 40 -14.864864 -1.86622 -0.562601 -1.046775        1
# 41 -14.864864 -1.86622 -0.562601 -1.046775        1
# 42 -14.864864 -1.86622 -0.562601 -1.046775        1
# 43 -14.864864 -1.86622 -0.562601 -1.046775        1
# 44 -14.864864 -1.86622 -0.562601 -1.046775        1
# 45 -14.864864 -1.86622 -0.562601 -1.046775        1
# 46 -14.864864 -1.86622 -0.562601 -1.046775        1
# 47 -14.864864 -1.86622 -0.562601 -1.046775        1
# 48 -14.864864 -1.86622 -0.562601 -1.046775        1
# 49 -14.864864 -1.86622 -0.562601 -1.046775        1
# 50 -14.864864 -1.86622 -0.562601 -1.046775        1
# 51 -14.864864 -1.86622 -0.562601 -1.046775        1
# 52 -14.864864 -1.86622 -0.562601 -1.046775        1
# 53 -14.864864 -1.86622 -0.562601 -1.046775        1
# 54 -14.864864 -1.86622 -0.562601 -1.046775        1
# 55 -14.864864 -1.86622 -0.562601 -1.046775        1
# 56 -14.864864 -1.86622 -0.562601 -1.046775        1
# 57 -14.864864 -1.86622 -0.562601 -1.046775        1
# 58 -14.864864 -1.86622 -0.562601 -1.046775        1
# 59 -14.864864 -1.86622 -0.562601 -1.046775        1
# 60 -14.864864 -1.86622 -0.562601 -1.046775        1
# 61 -14.864864 -1.86622 -0.562601 -1.046775        1
# 62 -14.864864 -1.86622 -0.562601 -1.046775        1
# 63 -14.864864 -1.86622 -0.562601 -1.046775        1
# 64 -14.864864 -1.86622 -0.562601 -1.046775        1
# 65 -14.864864 -1.86622 -0.562601 -1.046775        1
# 66 -14.864864 -1.86622 -0.562601 -1.046775        1
# 67 -14.864864 -1.86622 -0.562601 -1.046775        1
# 68 -14.864864 -1.86622 -0.562601 -1.046775        1
# 69 -14.864864 -1.86622 -0.562601 -1.046775        1
# 70 -14.864864 -1.86622 -0.562601 -1.046775        1
# 71 -14.864864 -1.86622 -0.562601 -1.046775        1
# 72 -14.864864 -1.86622 -0.562601 -1.046775        1
# 73 -14.864864 -1.86622 -0.562601 -1.046775        1
# 74 -14.864864 -1.86622 -0.562601 -1.046775        1
# 75 -14.864864 -1.86622 -0.562601 -1.046775        1
# 76 -14.864864 -1.86622 -0.562601 -1.046775        1
# 77 -14.864864 -1.86622 -0.562601 -1.046775        1
# 78 -14.864864 -1.86622 -0.562601 -1.046775        1
# 79 -14.864864 -1.86622 -0.562601 -1.046775        1
# 80 -14.864864 -1.86622 -0.562601 -1.046775        1
# 81 -14.864864 -1.86622 -0.562601 -1.046775        1
# 82 -14.864864 -1.86622 -0.562601 -1.046775        1
# 83 -14.864864 -1.86622 -0.562601 -1.046775        1
# 84 -14.864864 -1.86622 -0.562601 -1.046775        1
# 85 -14.864864 -1.86622 -0.562601 -1.046775        1
# 86 -14.864864 -1.86622 -0.562601 -1.046775        1
# 87 -14.864864 -1.86622 -0.562601 -1.046775        1
# 88 -14.864864 -1.86622 -0.562601 -1.046775        1
# 89 -14.864864 -1.86622 -0.562601 -1.046775        1
# 90 -14.864864 -1.86622 -0.562601 -1.046775        1
# 91 -14.864864 -1.86622 -0.562601 -1.046775        1
# 92 -14.864864 -1.86622 -0.562601 -1.046775        1
# 93 -14.864864 -1.86622 -0.562601 -1.046775        1
# 94 -14.864864 -1.86622 -0.562601 -1.046775        1
# 95 -14.864864 -1.86622 -0.562601 -1.046775        1
# 96 -14.864864 -1.86622 -0.562601 -1.046775        1
# 97 -14.864864 -1.86622 -0.562601 -1.046775        1
# 98 -14.864864 -1.86622 -0.562601 -1.046775        1
# 99 -14.864864 -1.86622 -0.562601 -1.046775        1

# %%
print(len(x_test_rolled)/30)
print(len(x_test)-29)
# Out:
# 105540.0
# 105540

# %%
x_test_rolled.drop(['id','dummy_id'], axis=1, inplace=True)
x_test_rolled = np.reshape(x_test_rolled.to_numpy(dtype=np.float64), [-1 , 30, int(x_test_rolled.shape[1])])
x_test_rolled.shape
# Out:
# (105540, 30, 10)

# %%
x_test_fft = np.copy(x_test_rolled)
x_test_fft = np.apply_along_axis(absfft, 1, x_test_fft)
x_test_fft
# Out:
# array([[[5.00905621e+00, 9.45408046e+00, 3.01820915e+01, ...,
#          5.59866143e+01, 1.68780394e+01, 3.14032524e+01],
#         [0.00000000e+00, 0.00000000e+00, 1.24860292e-15, ...,
#          2.49720583e-15, 0.00000000e+00, 0.00000000e+00],
#         [6.34815699e-17, 0.00000000e+00, 5.07852559e-16, ...,
#          1.01570512e-15, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [1.34934242e-17, 0.00000000e+00, 1.07947394e-16, ...,
#          2.15894788e-16, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 1.31233455e-16, ...,
#          2.62466909e-16, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[5.11272906e+00, 9.06701819e+00, 3.01820915e+01, ...,
#          5.59866143e+01, 1.68780394e+01, 3.14032524e+01],
#         [1.03672855e-01, 3.87062265e-01, 1.24860292e-15, ...,
#          2.49720583e-15, 0.00000000e+00, 0.00000000e+00],
#         [1.03672855e-01, 3.87062265e-01, 5.07852559e-16, ...,
#          1.01570512e-15, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [1.03672855e-01, 3.87062265e-01, 1.07947394e-16, ...,
#          2.15894788e-16, 0.00000000e+00, 0.00000000e+00],
#         [1.03672855e-01, 3.87062265e-01, 1.31233455e-16, ...,
#          2.62466909e-16, 0.00000000e+00, 0.00000000e+00],
#         [1.03672855e-01, 3.87062265e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[5.22327818e+00, 9.04134570e+00, 3.01820915e+01, ...,
#          5.59866143e+01, 1.68780394e+01, 3.14032524e+01],
#         [2.13049652e-01, 4.12208316e-01, 1.24860292e-15, ...,
#          2.49720583e-15, 0.00000000e+00, 0.00000000e+00],
#         [2.09545583e-01, 4.10648038e-01, 5.07852559e-16, ...,
#          1.01570512e-15, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [4.50442451e-02, 3.63759174e-01, 1.07947394e-16, ...,
#          2.15894788e-16, 0.00000000e+00, 0.00000000e+00],
#         [2.34132684e-02, 3.61990127e-01, 1.31233455e-16, ...,
#          2.62466909e-16, 0.00000000e+00, 0.00000000e+00],
#         [6.87626077e-03, 3.61389768e-01, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[1.53970410e+01, 7.61598600e-01, 1.51933105e+01, ...,
#          1.69942999e+01, 1.22133799e+01, 9.31877880e+00],
#         [1.91416683e+01, 6.52856983e+00, 0.00000000e+00, ...,
#          2.14080008e+00, 6.93292670e-01, 1.32801633e+00],
#         [2.19277924e+00, 7.65084540e+00, 2.53926279e-16, ...,
#          1.96765244e+00, 4.38998559e-01, 5.92374018e-01],
#         ...,
#         [1.12790137e+00, 1.43655315e+00, 5.39736969e-17, ...,
#          4.11217902e-01, 2.11950358e-01, 6.75130916e-02],
#         [1.01522644e+00, 1.41526668e+00, 0.00000000e+00, ...,
#          2.21974516e-01, 2.65985639e-01, 4.36926037e-02],
#         [9.90710493e-01, 1.42778580e+00, 0.00000000e+00, ...,
#          1.73619957e-02, 3.13164247e-01, 3.42993651e-02]],
#
#        [[1.33230550e+01, 3.56142430e-01, 1.51933105e+01, ...,
#          1.75512915e+01, 1.24625591e+01, 9.47303435e+00],
#         [1.92861004e+01, 7.62914179e+00, 0.00000000e+00, ...,
#          2.63870041e+00, 7.83091004e-01, 1.44972666e+00],
#         [6.40438255e-01, 6.61466922e+00, 2.53926279e-16, ...,
#          2.30035654e+00, 4.26538222e-01, 7.31401381e-01],
#         ...,
#         [1.10188783e+00, 1.28888930e+00, 5.39736969e-17, ...,
#          2.74751965e-01, 2.92918174e-01, 8.88235212e-02],
#         [1.05901795e+00, 8.46308128e-01, 0.00000000e+00, ...,
#          4.69568034e-01, 2.02152073e-01, 1.12051997e-01],
#         [1.08327554e+00, 3.10044773e-01, 0.00000000e+00, ...,
#          5.39629595e-01, 6.39851019e-02, 1.19956186e-01]],
#
#        [[1.13664943e+01, 8.22648289e-02, 1.51933105e+01, ...,
#          1.81082831e+01, 1.27219441e+01, 9.67436415e+00],
#         [1.92172091e+01, 7.19125318e+00, 0.00000000e+00, ...,
#          3.10769084e+00, 8.97507286e-01, 1.63571172e+00],
#         [1.77095990e+00, 7.05307327e+00, 2.53926279e-16, ...,
#          2.53252548e+00, 4.58982503e-01, 9.32702961e-01],
#         ...,
#         [8.56511715e-01, 1.31054865e+00, 5.39736969e-17, ...,
#          5.25140671e-01, 1.06543786e-01, 1.34690675e-01],
#         [9.39846028e-01, 1.02388599e+00, 0.00000000e+00, ...,
#          3.19861261e-01, 2.33864561e-01, 9.96291823e-02],
#         [8.73285117e-01, 1.28362486e-01, 0.00000000e+00, ...,
#          1.73619957e-02, 3.23370080e-01, 8.13736147e-02]]])

# %%
print(x_test_rolled.shape)
print(x_test_fft.shape)
# Out:
# (105540, 30, 10)
# (105540, 16, 10)

# %%
# num_vars = x_test_rolled.shape[2]
# for i in range(num_vars):
#     mean_s = np.mean(x_test_rolled[:,:,i])
#     sd_s = np.std(x_test_rolled[:,:,i])
#     x_test_rolled[:,:,i] = (x_test_rolled[:,:,i]-mean_s)/sd_s

# num_vars_fft = x_test_fft.shape[2]
# for i in range(num_vars_fft):
#     mean_s = np.mean(x_test_fft[:,:,i])
#     sd_s = np.std(x_test_fft[:,:,i])
#     x_test_fft[:,:,i] = (x_test_fft[:,:,i]-mean_s)/sd_s

# %%
x_test = x_test_rolled.transpose(0,2,1)
x_test_fft = x_test_fft.transpose(0,2,1)

# %%
print(x_test.shape)
print(x_test_fft.shape)
# Out:
# (105540, 10, 30)
# (105540, 10, 16)

# %%
device_test = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device_test = torch.device('cpu')

# %%
model.to(device_test)
# Out:
# Classifier(
#   (raw): Sequential(
#     (0): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(10, 10, kernel_size=(8,), stride=(2,), padding=(4,), groups=10)
#           (pointwise): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(32, 32, kernel_size=(8,), stride=(2,), padding=(3,), groups=32)
#           (pointwise): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (2): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(64, 64, kernel_size=(8,), stride=(2,), padding=(5,), groups=64)
#           (pointwise): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (3): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(2,), groups=128)
#           (pointwise): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (4): Flatten()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=256, out_features=64, bias=True)
#     (10): ReLU(inplace=True)
#   )
#   (fft): Sequential(
#     (0): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(10, 10, kernel_size=(8,), stride=(2,), padding=(3,), groups=10)
#           (pointwise): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(32, 32, kernel_size=(8,), stride=(2,), padding=(5,), groups=32)
#           (pointwise): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (2): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(64, 64, kernel_size=(8,), stride=(2,), padding=(4,), groups=64)
#           (pointwise): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (3): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(5,), groups=128)
#           (pointwise): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (4): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(3,), groups=128)
#           (pointwise): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (5): Flatten()
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=512, out_features=256, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Dropout(p=0.5, inplace=False)
#     (10): Linear(in_features=256, out_features=64, bias=True)
#     (11): ReLU(inplace=True)
#   )
#   (out): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=64, out_features=20, bias=True)
#   )
# )

# %%
test_ds = TensorDataset(torch.tensor(x_test).float(),
                        torch.tensor(x_test_fft).float())

# %%
test_dl = DataLoader(test_ds, batch_size=1, shuffle=False)
test_preds = []

# %%
model.eval()
model.to(device_test)
# Out:
# Classifier(
#   (raw): Sequential(
#     (0): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(10, 10, kernel_size=(8,), stride=(2,), padding=(4,), groups=10)
#           (pointwise): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(32, 32, kernel_size=(8,), stride=(2,), padding=(3,), groups=32)
#           (pointwise): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (2): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(64, 64, kernel_size=(8,), stride=(2,), padding=(5,), groups=64)
#           (pointwise): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (3): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(2,), groups=128)
#           (pointwise): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (4): Flatten()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=256, out_features=64, bias=True)
#     (10): ReLU(inplace=True)
#   )
#   (fft): Sequential(
#     (0): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(10, 10, kernel_size=(8,), stride=(2,), padding=(3,), groups=10)
#           (pointwise): Conv1d(10, 32, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(32, 32, kernel_size=(8,), stride=(2,), padding=(5,), groups=32)
#           (pointwise): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (2): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(64, 64, kernel_size=(8,), stride=(2,), padding=(4,), groups=64)
#           (pointwise): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (3): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(5,), groups=128)
#           (pointwise): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (4): SepConv1d(
#       (layers): Sequential(
#         (0): _SepConv1d(
#           (depthwise): Conv1d(128, 128, kernel_size=(8,), stride=(2,), padding=(3,), groups=128)
#           (pointwise): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         )
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (5): Flatten()
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=512, out_features=256, bias=True)
#     (8): ReLU(inplace=True)
#     (9): Dropout(p=0.5, inplace=False)
#     (10): Linear(in_features=256, out_features=64, bias=True)
#     (11): ReLU(inplace=True)
#   )
#   (out): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=64, out_features=20, bias=True)
#   )
# )

# %%
for test_batch in tqdm(test_dl):
    x_raw, x_fft = [t.to(device_test) for t in test_batch]
    out = model(x_raw, x_fft)
    preds = F.log_softmax(out, dim=1).argmax(dim=1)
    decoded_preds = le_y.inverse_transform([preds.detach().cpu().clone().numpy()])
    test_preds.append([i for i in decoded_preds[0]])
# Out:
#   0%|          | 0/105540 [00:00<?, ?it/s]/home/starlet/anaconda3/envs/spconv12cuda11/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|██████████| 105540/105540 [03:33<00:00, 494.86it/s]

# %%
predictions = pd.DataFrame(np.array(test_preds)).reset_index()
predictions.columns = ['id', 'ac', 'ev', 'oven', 'wash', 'dryer']
predictions['id'] = predictions['id'] +1
predictions.set_index('id',inplace=True)
predictions
# Out:
#        ac ev oven wash dryer
# id
# 1       1  0    0    0     0
# 2       1  0    0    0     0
# 3       1  0    0    0     0
# 4       1  0    0    0     0
# 5       1  0    0    0     0
# ...    .. ..  ...  ...   ...
# 105536  0  0    0    0     0
# 105537  0  0    0    0     0
# 105538  0  0    0    0     0
# 105539  0  0    0    0     0
# 105540  0  0    0    0     0
#
# [105540 rows x 5 columns]

# %%
predictions[['ac', 'ev', 'oven', 'wash', 'dryer']].drop_duplicates()
# Out:
#       ac ev oven wash dryer
# id
# 1      1  0    0    0     0
# 43     0  0    0    0     0
# 25515  1  1    0    0     0
# 25527  0  0    1    0     0
# 25550  1  0    1    0     0
# 28442  0  1    0    0     0

# %%
predictions.to_csv('../CNN_predictions.csv')

# %%
[i for i in decoded_preds[0]]

# %%
pd.read_csv('../naive.csv')

# %%
pd.DataFrame(np.array([[i for i in decoded_preds[0]],[i for i in decoded_preds[0]]], dtype=np.int16()))

# %%
y_train.drop_duplicates()

# %%
le_y.inverse_transform([9])

# %%
test = np.load('./np_x_train_rolled_new.npy', allow_pickle= True)

# %%
np.array(test,dtype = np.float64)

# %%
x_train_rolled.to_numpy(dtype=np.float64).dtype

# %%
np.vstack(x_train_rolled[:, 0:1]).astype(np.float)

# %%
x_train_rolled.drop('id', axis=1, inplace=True)
x_train_rolled

# %%
y_train.shape

# %%
# x_train_rolled = pd.concat([roll_time_series(temp, column_id="dummy_id", column_sort="id",
#             max_timeshift = 29, min_timeshift = 29),x_train_rolled]).reset_index(drop = True)

# %%
# np.save("np_x_train_rolled_new.npy",np.array(x_train_rolled))

# %%
print(x_train)

# %%
# x_train.drop(x_train.index[0:29])
x_train.head(100)

# %%
#

# %% [markdown]
# ## no need now - additional features calculators

# %%
x_features = extract_features(x_train_rolled.loc[0:299999],column_id='id',column_sort='ids', 
                 default_fc_parameters=EfficientFCParameters())

# %%
x_features.shape

# %%
len(x_train_rolled.loc[0:299999,'id'].value_counts())

# %%
from tsfresh.feature_selection.significance_tests import target_real_feature_real_test
x_features_dropped = x_features.dropna(axis=1, how='any')
keeps = {}
for col in x_features_dropped.columns:
    p_value = target_real_feature_real_test(x_features_dropped[col].reset_index().drop(columns=["level_0","level_1"],
                                                                       axis = 1).squeeze(), 
                                     pd.Series(y_train_transformed[29:(29+60130)]))
    if p_value < 0.01:
        keeps[col] = p_value

# %%
best_features = sorted(list(dict(sorted(keeps.items(), key=lambda item: item[1])).keys())[:255])
x_features = x_features[best_features]

# %%
x_features['ids'] = x_features.index
x_train_rolled_temp = x_train_rolled.loc[0:299999]

# %%
x_train_temp = x_train_rolled_temp.merge(x_features, how='left', left_on="id", right_on="ids")

# %%
x_features

# %%
x_minimal = extract_features(x_train_rolled.loc[0:299999],column_id='id',column_sort='ids', 
                             default_fc_parameters=MinimalFCParameters())
x_minimal.shape

# %%
len(y_train_transformed)

# %%
tsfresh.feature_selection.significance_tests.target_real_feature_real_test(x_minimal['load__standard_deviation'].reset_index().drop(columns=["level_0","level_1"], axis = 1).squeeze(), 
                                                                               pd.Series(y_train_transformed[29:(29+60130)]))

# %%
x_minimal.head(10000)

# %%
pd.set_option('display.max_rows', 10000)
data.head(10000)

# %%
pd.reset_option('all')

# %%
data.columns

# %%
def absfft(x):
    return np.abs(np.fft.rfft(x))
x_train_fft = np.copy(x_train)
x_train_fft = np.apply_along_axis(absfft, 1, x_train_fft)
x_train_fft

# %%
x_train_fft.shape

# %%
x_train.shape

# %%
num_vars = x_train.shape[2]
for i in range(num_vars):
    mean_s = np.mean(x_train[:,:,i])
    sd_s = np.std(x_train[:,:,i])
    x_train[:,:,i] = (x_train[:,:,i]-mean_s)/sd_s

num_vars_fft = x_train_fft.shape[2]
for i in range(num_vars_fft):
    mean_s = np.mean(x_train_fft[:,:,i])
    sd_s = np.std(x_train_fft[:,:,i])
    x_train_fft[:,:,i] = (x_train_fft[:,:,i]-mean_s)/sd_s

# %%
x_train = x_train.transpose(0,2,1)
x_train_fft = x_train_fft.transpose(0,2,1)

# %%
x_train.shape

# %%
x_train_fft.shape

# %%
def build_datasets(data, target, train_size, valid_pct = 0.2, seed = None):
    x, x_fft = data
    idx = np.arange(train_size)
    train_idx, val_idx = train_test_split(idx, test_size = valid_pct, random_state = seed)
    train_ds = TensorDataset(torch.tensor(x[:train_size][train_idx]).float(),
                            torch.tensor(x_fft[:train_size][train_idx]).float(),
                            torch.tensor(target[:train_size][train_idx]).long())
    val_ds = TensorDataset(torch.tensor(x[:train_size][val_idx]).float(),
                            torch.tensor(x_fft[:train_size][val_idx]).float(),
                            torch.tensor(target[:train_size][val_idx]).long())
#     test_ds = TensorDataset(torch.tensor(x[train_size:]).float(),
#                             torch.tensor(x_fft[train_size:]).float(),
#                             torch.tensor(target[train_size:]).long())
    return train_ds, val_ds #, test_ds

# %%
def build_loaders(data, batch_size = 128, jobs = 8):
#     train_ds, valid_ds, test_ds = data
    train_ds, valid_ds = data
    train_dl = DataLoader(train_ds, batch_size = batch_size, shuffle = False, num_workers = jobs)
    valid_dl = DataLoader(valid_ds, batch_size = batch_size, shuffle = False, num_workers = jobs)
#     test_dl = DataLoader(test_ds, batch_size = batch_size, shuffle = True, num_workers = jobs)
    return train_dl, valid_dl #, test_dl

# %%
class _SepConv1d(nn.Module):
    """A simple separable convolution implementation.
    
    The separable convlution is a method to reduce number of the parameters 
    in the deep learning network for slight decrease in predictions quality.
    """
    def __init__(self, ni, no, kernel, stride, pad):
        super().__init__()
        self.depthwise = nn.Conv1d(ni, ni, kernel, stride, padding=pad, groups=ni)
        self.pointwise = nn.Conv1d(ni, no, kernel_size=1)

    def forward(self, x):
        return self.pointwise(self.depthwise(x))

# %%
class SepConv1d(nn.Module):
    """Implementes a 1-d convolution with 'batteries included'.
    
    The module adds (optionally) activation function and dropout layers right after
    a separable convolution layer.
    """
    def __init__(self, ni, no, kernel, stride, pad, drop=None,
                 activ=lambda: nn.ReLU(inplace=True)):
    
        super().__init__()
        assert drop is None or (0.0 < drop < 1.0)
        layers = [_SepConv1d(ni, no, kernel, stride, pad)]
        if activ:
            layers.append(activ())
        if drop is not None:
            layers.append(nn.Dropout(drop))
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x): 
        return self.layers(x)

# %%
class Flatten(nn.Module):
    """Converts N-dimensional tensor into 'flat' one."""

    def __init__(self, keep_batch_dim=True):
        super().__init__()
        self.keep_batch_dim = keep_batch_dim

    def forward(self, x):
        if self.keep_batch_dim:
            return x.view(x.size(0), -1)
        return x.view(-1)

# %%
class PrintSize(nn.Module):
    def __init__(self):
        super(PrintSize, self).__init__()
        
    def forward(self, x):
        print(x.shape)
        return x

# %%
class Classifier(nn.Module):
    def __init__(self, raw_ni, fft_ni, no, drop=.5):
        super().__init__()
        #PKS [[3,8,2],[3,8,4],[3,8,2],[3,8,2]]
        self.raw = nn.Sequential( #kernel, stride, pad
            SepConv1d(raw_ni,  32, 8, 2, 3, drop=drop),
            SepConv1d(    32,  64, 8, 4, 3, drop=drop),
            SepConv1d(    64, 128, 8, 2, 3, drop=drop),
            SepConv1d(   128, 256, 8, 2, 3),
            Flatten(),
#             PrintSize(),
            nn.Dropout(drop), nn.Linear(512, 256), nn.ReLU(inplace=True),
            nn.Dropout(drop), nn.Linear( 256, 64), nn.ReLU(inplace=True))
        #PKS [[5,8,3],[4,8,2],[5,8,3],[5,8,3],[4,8,3]]
        self.fft = nn.Sequential(
            SepConv1d(fft_ni,  32, 8, 3, 5, drop=drop),
            SepConv1d(    32,  64, 8, 2, 4, drop=drop),
            SepConv1d(    64, 128, 8, 3, 5, drop=drop),
            SepConv1d(   128, 128, 8, 3, 5, drop=drop),
            SepConv1d(   128, 256, 8, 3, 4),
            Flatten(),
#             PrintSize(),
            nn.Dropout(drop), nn.Linear(512, 256), nn.ReLU(inplace=True),
            nn.Dropout(drop), nn.Linear( 256, 64), nn.ReLU(inplace=True))
        
        self.out = nn.Sequential(
            nn.Linear(128, 64), nn.ReLU(inplace=True), nn.Linear(64, no))
        
    def forward(self, t_raw, t_fft):
        raw_out = self.raw(t_raw)
        fft_out = self.fft(t_fft)
        t_in = torch.cat([raw_out, fft_out], dim=1)
        out = self.out(t_in)
        return out

# %%
seed = 1
train_size = len(x_train)
datasets = build_datasets((x_train, x_train_fft), y_train_transformed, train_size,valid_pct = 0.2, seed=seed)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')

# %%
raw_feat = x_train.shape[1]
fft_feat = x_train_fft.shape[1]
# trn_dl, val_dl, tst_dl = build_loaders(datasets, batch_size=256)
trn_dl, val_dl = build_loaders(datasets, batch_size=1024)

lr = 0.0002
n_epochs = 3000
iterations_per_epoch = len(trn_dl)
num_classes = 20
best_acc = 0
patience, trials = 3000, 0
base = 1
step = 2
loss_history = []
acc_history = []
gstep = -1
model = Classifier(raw_feat, fft_feat, num_classes,drop = .5).to(device)
criterion = nn.CrossEntropyLoss(reduction='sum')
opt = torch.optim.Adam(model.parameters(), lr=lr, weight_decay= 0.0001)
lr_scheduler = torch.optim.lr_scheduler.OneCycleLR(opt, 0.004, steps_per_epoch = len(datasets[0]),epochs = n_epochs,
                                                  pct_start = 0.4,base_momentum = 0.85, max_momentum=0.95,
                                                  div_factor = 10.0, last_epoch = gstep)
print('Start model training')

for epoch in range(1, n_epochs + 1):
    
    model.train()
    epoch_loss = 0
    for i, batch in enumerate(trn_dl):
        
        x_raw, x_fft, y_batch = [t.to(device) for t in batch]
        opt.zero_grad()
        out = model(x_raw, x_fft)
        loss = criterion(out, y_batch)
        epoch_loss += loss.item()
        loss.backward()
        opt.step()
        lr_scheduler.step()
        
    epoch_loss /= train_size
    loss_history.append(epoch_loss)
    
    model.eval()
    correct, total = 0, 0
    for batch in val_dl:
        x_raw, x_fft, y_batch = [t.to(device) for t in batch]
        out = model(x_raw, x_fft)
        preds = F.log_softmax(out, dim=1).argmax(dim=1)
        total += y_batch.size(0)
        correct += (preds == y_batch).sum().item()
    
    acc = correct / total
    acc_history.append(acc)

    if epoch % base == 0:
        print(f'Epoch: {epoch:3d}. Loss: {epoch_loss:.4f}. Acc.: {acc:2.2%}')
        base *= step

    if acc > best_acc:
        trials = 0
        best_acc = acc
        torch.save(model.state_dict(), 'best.pth')
        print(f'Epoch {epoch} best model saved with accuracy: {best_acc:2.2%}')
    else:
        trials += 1
        if trials >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
            
print('Done!')

# %%
y_batch

# %%
y_train.encoded.unique()

# %%
criterion(out, torch.tensor([1]))

# %%
l = 9
pks = [[3,8,2],[2,8,4],[2,8,4],[2,8,4]]
for i, layer in enumerate(pks):
    p,k,s = layer
    l = (l + 2*p - k)/s + 1
    print(f"length: {l}")

# %%
l = 6
pks = [[4,8,2],[4,8,2],[4,8,4],[4,8,4],[3,8,2]]
for i, layer in enumerate(pks):
    p,k,s = layer
    l = (l + 2*p - k)/s + 1
    print(f"length: {l}")

# %%
l = 30
pks = [[4,8,2],[3,8,2],[5,8,2],[2,8,2]]
for i, layer in enumerate(pks):
    p,k,s = layer
#     w = (w + 2*p - k)/s + 1
#     h = (h + 2*p - k)/s + 1
    l = (l + 2*p - k)/s + 1
    print(f"length: {l}")

# %%
l = 12
pks = [[3,8,2],[5,8,2],[4,8,2],[5,8,2],[3,8,2]]
for i, layer in enumerate(pks):
    p,k,s = layer
#     w = (w + 2*p - k)/s + 1
#     h = (h + 2*p - k)/s + 1
    l = (l + 2*p - k)/s + 1
    print(f"length: {l}")

# %%
        #PKS [[4,8,2],[3,8,2],[5,8,2],[2,8,2]]
        self.raw = nn.Sequential( #kernel, stride, pad
            SepConv1d(raw_ni,  32, 8, 2, 4, drop=drop),
            SepConv1d(    32,  64, 8, 2, 3, drop=drop),
            SepConv1d(    64, 128, 8, 2, 5, drop=drop),
            SepConv1d(   128, 256, 8, 2, 2, drop=drop),
            Flatten(),
#             PrintSize(),
            nn.Dropout(drop), nn.Linear(512, 256), nn.ReLU(inplace=True),
            nn.Dropout(drop), nn.Linear( 256, 64), nn.ReLU(inplace=True))
        #PKS [3,8,2],[5,8,2],[4,8,2],[5,8,2],[3,8,2]

# %%
count_hourly = x_train.loc[:,:].groupby(["dayofweek",'hourofday']).count()
count_hourly.reset_index(inplace=True)

# %%
count_hourly

# %%
x_train.sort_values(by=["dayofweek",'hourofday']).head(1000)

# %%
x_train = x_train.sort_values(by=["dayofweek",'hourofday'])

# %%
x_train[(x_train.dayofweek == "Fri") & (x_train.hourofday == 11)].first_valid_index()

# %%
min_hourly_obs = min(count_hourly['var'].values) 
drop_idx = []
for _, row in count_hourly.iterrows():
    drop_idx = [*drop_idx,*x_train[(x_train.dayofweek == row[0]) & (x_train.hourofday == row[1])].index.values[0:row[2] - min_hourly_obs]]
drop_idx

# %%
x_train.drop(index = drop_idx, inplace = True)
x_train.loc[:,:].groupby(["dayofweek",'hourofday']).count()

# %%
x_train

# %%
a = [123]
b = list(range(1,4))
a + b

# %%
min_hourly_obs

# %%
df = pd.DataFrame({
   "id": [1, 1, 1, 1, 2, 2],
   "time": [1, 2, 3, 4, 8, 9],
   "x": [1, 2, 3, 4, 10, 11],
   "y": [5, 6, 7, 8, 12, 13],
})

# %%
x_train.shape

# %%
from tsfresh.utilities.dataframe_functions import roll_time_series
df_rolled = roll_time_series(x_train[['load','dummy_id','id']], column_id="dummy_id", column_sort="id",
                            max_timeshift = 29, min_timeshift = 29)
df_rolled

# %%
from tsfresh.utilities.dataframe_functions import roll_time_series
df_rolled = roll_time_series(df, column_id="id", column_sort="time", max_timeshift=2, min_timeshift=2)
df_rolled

# %%
from tsfresh import extract_features
df_features = extract_features(df_rolled, column_id="id", column_sort="time", )

# %%
df_features

# %%
x_train.loc[0:500, ['load','dummy_id','id']]
